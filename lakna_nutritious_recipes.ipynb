# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Setup

# %%
# Import libraries
import os
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import linregress, pearsonr
import requests

# Import API keys
#from alyssa_config import spoonacular_key, rapidapi_key
from lakna_config import spoonacular_key

# %%
# Check number of items in the Resources subdirectories, to automate file naming.
def recipe_folder():
    count = len(os.listdir('Resources/01_recipe_IDs'))-1
    return(count)

def raw_folder():
    count = len(os.listdir('Resources/02_raw_data'))-1
    return(count)

def simple_folder():
    count = len(os.listdir('Resources/03_simplified_data'))-1
    return(count)

def complex_folder():
    count = len(os.listdir('Resources/04_complex_test'))-1
    return(count)

# %%
# Request user input for 'initial_recipes' index of interest.
def check_index():
    try:
        select_folder = input(f"Select file type (recipe, raw, simple, complex): ")
        if (select_folder == "recipe"):
            get_count = recipe_folder()
        elif (select_folder == "raw"):
            get_count = raw_folder()
        elif (select_folder == "simple"):
            get_count = simple_folder()
        elif (select_folder == "complex"):
            get_count = complex_folder()
    except ValueError as e:
        print(f"{e}: Selected file type unknown.")

    try:
        # index = int(input(f"Select file number (0-{recipe_folder()-1}): "))
        index = int(input(f"Select file number (0-{get_count-1}): "))
        return index
    except ValueError as e:
        print(f"{e}: Integer required.")

# %% [markdown]
# ## Initial Data Exploration - FOOD.COM Dataset
# __Goal:__ Understand dataset format and identify attributes.
#
# __PROCESS__
# 1. Extract the ratings from `RAW_interactions.csv` first.
# 2. Merge with the `RAW_recipes.csv` then investigate the dataset.
#
# __OBSERVATIONS__
# - Nutrition headings: calories (#), total fat (PDV), sugar (PDV) , sodium (PDV) , protein (PDV) , saturated fat (PDV), carbohydrates (PDV)
# - Will need to convert the nutrition PDV to actual values later by defining a caloric diet level.

# %%
# Import the FOOD.COM datasets as DataFrames.
food_df = pd.read_csv('Resources/RAW_recipes.csv')
interactions_df = pd.read_csv('Resources/RAW_interactions.csv')

# %%
# Get the DataFrame dimensions
interactions_shape = interactions_df.shape
print(f"interactions_df: {interactions_shape}")

# Display the DataFrame
interactions_df.head()
# Out:
# interactions_df: (1132367, 5)
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
# 2     8937      44394  2002-12-01       4
# 3   126440      85009  2010-02-27       5
# 4    57222      85009  2011-10-01       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 2  This worked very well and is EASY.  I used not...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...

# %%
# Get the DataFrame dimensions and columns
food_shape = food_df.shape
print(f"food_df: {food_shape}")
print(food_df.columns)

# Display the DataFrame
food_df.head()
# Out:
# food_df: (231637, 12)
# Index(['name', 'id', 'minutes', 'contributor_id', 'submitted', 'tags',
#        'nutrition', 'n_steps', 'steps', 'description', 'ingredients',
#        'n_ingredients'],
#       dtype='object')
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %% [markdown]
# ### Calculate the Average Recipe Rating

# %%
# Check how many recipes have ratings
unique_ratings = len(interactions_df['recipe_id'].unique())
print(f"{unique_ratings} out of {food_shape[0]} have ratings.")

# Check how many recipes have a '0' rating
zero_rating = interactions_df.loc[interactions_df['rating'] == 0]['recipe_id'].unique()
print(f"There are {len(zero_rating)} recipes with a '0' rating.")

# Drop the rows with a '0' rating
nonzero_df = interactions_df.loc[interactions_df['rating'] != 0]
print(f"nonzero_df: {nonzero_df.shape}")
# Out:
# 231637 out of 231637 have ratings.
# There are 35114 recipes with a '0' rating.
# nonzero_df: (1071520, 5)

# %%
# Create a DataFrame with the average ratings per recipe ID
food_ratings = nonzero_df.groupby('recipe_id')['rating'].mean().reset_index()

# Display the DataFrame
food_ratings.head()
# Out:
#    recipe_id    rating
# 0         38  4.250000
# 1         39  3.000000
# 2         40  4.333333
# 3         41  4.500000
# 4         43  1.000000

# %%
# Rename the recipe ID column for merging with food_df
food_ratings = food_ratings.rename(columns={'recipe_id': 'id'})

# Merge the datasets and display updated DataFrame
merged_food = pd.merge(food_df, food_ratings, on='id')

# Display the DataFrame
merged_shape = merged_food.shape
print(f"merged_food: {merged_shape}")
merged_food.head()
# Out:
# merged_food: (226590, 13)
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients    rating
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7  5.000000
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6  4.666667
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13  4.000000
# 3  ['spreadable cheese with garlic and herbs', 'n...             11  4.500000
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8  5.000000

# %% [markdown]
# ### Parse the Nutrition Values

# %%
# Identify how to split the nutrition string and convert to float
test_string = merged_food['nutrition']

# Remove the square brackets
test_string = test_string[0].strip("[]")

# Split the string to a list
test_string = test_string.split(", ")

# Cast values to float
test_string = [float(value) for value in test_string]
test_string
# Out:
# [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]

# %%
# Parse each value in the `nutrition` column
# NOTE: calories (#), total fat (PDV), sugar (PDV), sodium (PDV) , protein (PDV), saturated fat, carbohydrates (PDV)
for df_idx, row in merged_food.iterrows():
    # Strip and split the string to a list
    values_list = row['nutrition'].strip("[]").split(", ")

    # Allocate each nutritional value to the correct column
    for idx, value in enumerate(values_list):
        if (idx == 0):
            merged_food.loc[df_idx, 'Calories'] = float(value)
        elif (idx == 1):
            merged_food.loc[df_idx, 'Total Fat (PDV)'] = float(value)
        elif (idx == 2):
            merged_food.loc[df_idx, 'Sugar (PDV)'] = float(value)
        elif (idx == 3):
            merged_food.loc[df_idx, 'Sodium (PDV)'] = float(value)
        elif (idx == 4):
            merged_food.loc[df_idx, 'Protein (PDV)'] = float(value)
        elif (idx == 5):
            merged_food.loc[df_idx, 'Saturated Fat (PDV)'] = float(value)
        elif (idx == 6):
            merged_food.loc[df_idx, 'Carbohydrates (PDV)'] = float(value)

# Display the DataFrame
merged_food.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients    rating  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7  5.000000
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6  4.666667
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13  4.000000
# 3  ['spreadable cheese with garlic and herbs', 'n...             11  4.500000
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8  5.000000
#
#    Calories  Total Fat (PDV)  Sugar (PDV)  Sodium (PDV)  Protein (PDV)  \
# 0      51.5              0.0         13.0           0.0            2.0
# 1     173.4             18.0          0.0          17.0           22.0
# 2     269.8             22.0         32.0          48.0           39.0
# 3     368.1             17.0         10.0           2.0           14.0
# 4     352.9              1.0        337.0          23.0            3.0
#
#    Saturated Fat (PDV)  Carbohydrates (PDV)
# 0                  0.0                  4.0
# 1                 35.0                  1.0
# 2                 27.0                  5.0
# 3                  8.0                 20.0
# 4                  0.0                 28.0

# %%
merged_food.shape
# Out:
# (226590, 20)

# %% [markdown]
# ### Identify Duplicate Recipes

# %%
# Determine whether there are duplicate recipes by ID
dup_id = len(merged_food['id'].unique())
print(f"Unique recipe IDs: {dup_id}, max number of recipes? {merged_shape[0] == dup_id}")

# Determine whether there are duplicate recipes by name
dup_name = len(merged_food['name'].unique())
print(f"Unique recipe names: {dup_name}, max number of recipes? {merged_shape[0] == dup_name}")

# Get the duplicate names - these should be okay
duplicate_names = merged_food.loc[merged_food.duplicated(['name'])]
duplicate_names.head()
# Out:
# Unique recipe IDs: 226590, max number of recipes? True
# Unique recipe names: 225190, max number of recipes? False
#                                     name      id  minutes  contributor_id  \
# 579              cream  of mushroom soup   51922       10           59064
# 819                         10 bean soup  470575      180         1020526
# 1275                  3 bean baked beans  313237       40          407338
# 1276                        3 bean salad  258846       15          607801
# 1294  3 ingredient peanut butter cookies  323810       13          138435
#
#        submitted                                               tags  \
# 579   2003-01-21  ['15-minutes-or-less', 'time-to-make', 'course...
# 819   2011-12-26  ['time-to-make', 'course', 'main-ingredient', ...
# 1275  2008-07-11  ['60-minutes-or-less', 'time-to-make', 'course...
# 1276  2007-10-13  ['15-minutes-or-less', 'time-to-make', 'course...
# 1294  2008-09-07  ['15-minutes-or-less', 'time-to-make', 'course...
#
#                                         nutrition  n_steps  \
# 579     [472.9, 64.0, 9.0, 38.0, 28.0, 19.0, 5.0]        3
# 819     [228.0, 10.0, 38.0, 47.0, 42.0, 8.0, 6.0]        9
# 1275   [329.9, 26.0, 48.0, 39.0, 33.0, 31.0, 9.0]       10
# 1276  [502.3, 44.0, 37.0, 41.0, 24.0, 19.0, 16.0]        6
# 1294    [197.1, 17.0, 74.0, 4.0, 11.0, 11.0, 6.0]       10
#
#                                                   steps  \
# 579   ['place walnuts , garlic water , nama shoyu , ...
# 819   ['finely chop onion , red and green bell peppe...
# 1275  ['fry bacon until crisp , reserving 2 teaspoon...
# 1276  ['in medium bowl combine mustard , vinegar and...
# 1294  ['preheat oven to 350', 'combine the three ing...
#
#                                             description  \
# 579   if you are not a raw food vegan then try this ...
# 819   we made this without the smoked turkey and ham...
# 1275  great for cookouts, family gatherings, potluck...
# 1276  i got this recipe from one of rachel ray's coo...
# 1294  this recipe is so simple.  sometimes i put cho...
#
#                                             ingredients  n_ingredients  \
# 579   ['walnuts', 'garlic', 'water', 'shoyu', 'rosem...              8
# 819   ['beans', 'onion', 'red bell pepper', 'green b...             13
# 1275  ['bacon', 'ground beef', 'onion', 'tomato sauc...             12
# 1276  ['cut green beans', 'dijon mustard', 'sugar', ...              9
# 1294  ['peanut butter', 'sugar', 'egg', 'chocolate c...              4
#
#         rating  Calories  Total Fat (PDV)  Sugar (PDV)  Sodium (PDV)  \
# 579   4.000000     472.9             64.0          9.0          38.0
# 819   5.000000     228.0             10.0         38.0          47.0
# 1275  4.000000     329.9             26.0         48.0          39.0
# 1276  4.000000     502.3             44.0         37.0          41.0
# 1294  4.857143     197.1             17.0         74.0           4.0
#
#       Protein (PDV)  Saturated Fat (PDV)  Carbohydrates (PDV)
# 579            28.0                 19.0                  5.0
# 819            42.0                  8.0                  6.0
# 1275           33.0                 31.0                  9.0
# 1276           24.0                 19.0                 16.0
# 1294           11.0                 11.0                  6.0

# %% [markdown]
# ### Parse the Tags

# %%
# Identify how to isolate each tag
tag_string = merged_food['tags'][0].strip("[]")
tag_string = tag_string.split(', ')
tag_string[0].strip("'")

# Get a list of unique tags
unique_tags = []
for string in merged_food['tags']:
    tag_list = string.strip("[]").split(', ')
    for word_idx in range(len(tag_list)):
        tag = tag_list[word_idx].strip("'")
        if tag not in unique_tags:
            unique_tags.append(tag)

# Display the tags alphabetically
print(f"Number of unique tags: {len(unique_tags)}")
sorted(unique_tags)
# Out:
# Number of unique tags: 547
# ['',
#  '1-day-or-more',
#  '15-minutes-or-less',
#  '3-steps-or-less',
#  '30-minutes-or-less',
#  '4-hours-or-less',
#  '5-ingredients-or-less',
#  '60-minutes-or-less',
#  'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.',
#  'a1-sauce',
#  'african',
#  'american',
#  'amish-mennonite',
#  'angolan',
#  'appetizers',
#  'apples',
#  'april-fools-day',
#  'argentine',
#  'artichoke',
#  'asian',
#  'asparagus',
#  'australian',
#  'austrian',
#  'avocado',
#  'bacon',
#  'baja',
#  'baked-beans',
#  'baking',
#  'bananas',
#  'bar-cookies',
#  'barbecue',
#  'bass',
#  'bean-soup',
#  'beans',
#  'beans-side-dishes',
#  'bear',
#  'beef',
#  'beef-barley-soup',
#  'beef-kidney',
#  'beef-liver',
#  'beef-organ-meats',
#  'beef-ribs',
#  'beef-sauces',
#  'beef-sausage',
#  'beginner-cook',
#  'beijing',
#  'belgian',
#  'berries',
#  'beverages',
#  'birthday',
#  'biscotti',
#  'bisques-cream-soups',
#  'black-bean-soup',
#  'black-beans',
#  'blueberries',
#  'bok-choys',
#  'brazilian',
#  'bread-machine',
#  'bread-pudding',
#  'breads',
#  'breakfast',
#  'breakfast-casseroles',
#  'breakfast-eggs',
#  'breakfast-potatoes',
#  'brewing',
#  'british-columbian',
#  'broccoli',
#  'broil',
#  'brown-bag',
#  'brown-rice',
#  'brownies',
#  'brunch',
#  'burgers',
#  'cabbage',
#  'cajun',
#  'cake-fillings-and-frostings',
#  'cakes',
#  'californian',
#  'cambodian',
#  'camping',
#  'canadian',
#  'candy',
#  'canning',
#  'cantonese',
#  'caribbean',
#  'carrots',
#  'casseroles',
#  'catfish',
#  'cauliflower',
#  'celebrity',
#  'central-american',
#  'chard',
#  'cheese',
#  'cheesecake',
#  'cherries',
#  'chick-peas-garbanzos',
#  'chicken',
#  'chicken-breasts',
#  'chicken-crock-pot',
#  'chicken-livers',
#  'chicken-stew',
#  'chicken-stews',
#  'chicken-thighs-legs',
#  'chilean',
#  'chili',
#  'chinese',
#  'chinese-new-year',
#  'chocolate',
#  'chocolate-chip-cookies',
#  'chowders',
#  'christmas',
#  'chutneys',
#  'cinco-de-mayo',
#  'citrus',
#  'clams',
#  'clear-soups',
#  'cobblers-and-crisps',
#  'cocktails',
#  'coconut',
#  'cod',
#  'coffee-cakes',
#  'collard-greens',
#  'college',
#  'colombian',
#  'comfort-food',
#  'condiments-etc',
#  'congolese',
#  'cookies-and-brownies',
#  'cooking-mixes',
#  'copycat',
#  'corn',
#  'costa-rican',
#  'course',
#  'crab',
#  'cranberry-sauce',
#  'crawfish',
#  'creole',
#  'crock-pot-main-dish',
#  'crock-pot-slow-cooker',
#  'crusts-pastry-dough-2',
#  'cuban',
#  'cuisine',
#  'cupcakes',
#  'curries',
#  'czech',
#  'dairy-free',
#  'danish',
#  'deep-fry',
#  'deer',
#  'dehydrator',
#  'desserts',
#  'desserts-easy',
#  'desserts-fruit',
#  'diabetic',
#  'dietary',
#  'dinner-party',
#  'dips',
#  'dips-lunch-snacks',
#  'dips-summer',
#  'drop-cookies',
#  'duck',
#  'duck-breasts',
#  'dutch',
#  'easter',
#  'easy',
#  'ecuadorean',
#  'egg-free',
#  'eggplant',
#  'eggs',
#  'eggs-breakfast',
#  'eggs-dairy',
#  'egyptian',
#  'elbow-macaroni',
#  'elk',
#  'english',
#  'equipment',
#  'ethiopian',
#  'european',
#  'fall',
#  'fathers-day',
#  'filipino',
#  'fillings-and-frostings-chocolate',
#  'finger-food',
#  'finnish',
#  'fish',
#  'flat-shapes',
#  'food-processor-blender',
#  'for-1-or-2',
#  'for-large-groups',
#  'for-large-groups-holiday-event',
#  'free-of-something',
#  'freezer',
#  'french',
#  'freshwater-fish',
#  'from-scratch',
#  'frozen-desserts',
#  'fruit',
#  'fudge',
#  'garnishes',
#  'gelatin',
#  'georgian',
#  'german',
#  'gifts',
#  'gluten-free',
#  'goose',
#  'grains',
#  'granola-and-porridge',
#  'grapes',
#  'greek',
#  'green-yellow-beans',
#  'greens',
#  'grilling',
#  'ground-beef',
#  'guatemalan',
#  'gumbo',
#  'halibut',
#  'halloween',
#  'halloween-cakes',
#  'halloween-cocktails',
#  'halloween-cupcakes',
#  'ham',
#  'ham-and-bean-soup',
#  'hand-formed-cookies',
#  'hanukkah',
#  'hawaiian',
#  'healthy',
#  'healthy-2',
#  'heirloom-historical',
#  'heirloom-historical-recipes',
#  'herb-and-spice-mixes',
#  'hidden-valley-ranch',
#  'high-calcium',
#  'high-fiber',
#  'high-in-something',
#  'high-in-something-diabetic-friendly',
#  'high-protein',
#  'holiday-event',
#  'honduran',
#  'hunan',
#  'hungarian',
#  'ice-cream',
#  'icelandic',
#  'independence-day',
#  'indian',
#  'indonesian',
#  'inexpensive',
#  'infant-baby-friendly',
#  'iranian-persian',
#  'iraqi',
#  'irish',
#  'irish-st-patricks-day',
#  'italian',
#  'jams-and-preserves',
#  'japanese',
#  'jellies',
#  'jewish-ashkenazi',
#  'jewish-sephardi',
#  'kid-friendly',
#  'kiwifruit',
#  'korean',
#  'kosher',
#  'kwanzaa',
#  'labor-day',
#  'lactose',
#  'lamb-sheep',
#  'laotian',
#  'lasagna',
#  'lasagne',
#  'lebanese',
#  'leftovers',
#  'lemon',
#  'lentils',
#  'less_thansql:name_topics_of_recipegreater_than',
#  'lettuces',
#  'libyan',
#  'lime',
#  'lobster',
#  'long-grain-rice',
#  'low-calorie',
#  'low-carb',
#  'low-cholesterol',
#  'low-fat',
#  'low-in-something',
#  'low-protein',
#  'low-saturated-fat',
#  'low-sodium',
#  'lunch',
#  'macaroni-and-cheese',
#  'mahi-mahi',
#  'main-dish',
#  'main-dish-beef',
#  'main-dish-chicken',
#  'main-dish-pasta',
#  'main-dish-pork',
#  'main-ingredient',
#  'malaysian',
#  'mango',
#  'manicotti',
#  'mardi-gras-carnival',
#  'marinades-and-rubs',
#  'marinara-sauce',
#  'mashed-potatoes',
#  'meat',
#  'meatballs',
#  'meatloaf',
#  'medium-grain-rice',
#  'melons',
#  'memorial-day',
#  'mexican',
#  'micro-melanesia',
#  'microwave',
#  'middle-eastern',
#  'middle-eastern-main-dish',
#  'midwestern',
#  'mixer',
#  'mongolian',
#  'moose',
#  'moroccan',
#  'mothers-day',
#  'muffins',
#  'mushroom-soup',
#  'mushrooms',
#  'mussels',
#  'namibian',
#  'native-american',
#  'nepalese',
#  'new-years',
#  'new-zealand',
#  'nigerian',
#  'no-cook',
#  'no-shell-fish',
#  'non-alcoholic',
#  'north-american',
#  'northeastern-united-states',
#  'norwegian',
#  'novelty',
#  'number-of-servings',
#  'nut-free',
#  'nuts',
#  'oamc-freezer-make-ahead',
#  'oatmeal',
#  'oaxacan',
#  'occasion',
#  'octopus',
#  'omelets-and-frittatas',
#  'one-dish-meal',
#  'onions',
#  'ontario',
#  'orange-roughy',
#  'oranges',
#  'oven',
#  'oysters',
#  'pacific-northwest',
#  'pakistani',
#  'palestinian',
#  'pancakes-and-waffles',
#  'papaya',
#  'passover',
#  'pasta',
#  'pasta-elbow-macaroni',
#  'pasta-rice-and-grains',
#  'pasta-rice-and-grains-elbow-macaroni',
#  'pasta-salad',
#  'pasta-shells',
#  'peaches',
#  'peanut-butter',
#  'pears',
#  'penne',
#  'pennsylvania-dutch',
#  'peppers',
#  'perch',
#  'peruvian',
#  'pheasant',
#  'pickeral',
#  'picnic',
#  'pies',
#  'pies-and-tarts',
#  'pineapple',
#  'pitted-fruit',
#  'pizza',
#  'plums',
#  'polish',
#  'polynesian',
#  'pork',
#  'pork-chops',
#  'pork-crock-pot',
#  'pork-loin',
#  'pork-loins',
#  'pork-loins-roast',
#  'pork-ribs',
#  'pork-sausage',
#  'portuguese',
#  'pot-pie',
#  'potatoes',
#  'potluck',
#  'poultry',
#  'preparation',
#  'prepared-potatoes',
#  'presentation',
#  'pressure-canning',
#  'pressure-cooker',
#  'puddings-and-mousses',
#  'puerto-rican',
#  'pumpkin',
#  'pumpkin-bread',
#  'punch',
#  'quail',
#  'quebec',
#  'quiche',
#  'quick-breads',
#  'rabbit',
#  'ragu-recipe-contest',
#  'ramadan',
#  'raspberries',
#  'ravioli-tortellini',
#  'refrigerator',
#  'reynolds-wrap',
#  'rice',
#  'roast',
#  'roast-beef',
#  'roast-beef-comfort-food',
#  'roast-beef-main-dish',
#  'rolled-cookies',
#  'rolls-biscuits',
#  'romantic',
#  'rosh-hashana',
#  'rosh-hashanah',
#  'russian',
#  'salad-dressings',
#  'salads',
#  'salmon',
#  'salsas',
#  'saltwater-fish',
#  'sandwiches',
#  'sauces',
#  'saudi-arabian',
#  'savory',
#  'savory-pies',
#  'savory-sauces',
#  'scallops',
#  'scandinavian',
#  'scones',
#  'scottish',
#  'seafood',
#  'seasonal',
#  'served-cold',
#  'served-hot',
#  'served-hot-new-years',
#  'shakes',
#  'shellfish',
#  'short-grain-rice',
#  'shrimp',
#  'side-dishes',
#  'side-dishes-beans',
#  'simply-potatoes',
#  'simply-potatoes2',
#  'small-appliance',
#  'smoker',
#  'smoothies',
#  'snacks',
#  'snacks-kid-friendly',
#  'snacks-sweet',
#  'sole-and-flounder',
#  'somalian',
#  'soul',
#  'soups-stews',
#  'sourdough',
#  'south-african',
#  'south-american',
#  'south-west-pacific',
#  'southern-united-states',
#  'southwestern-united-states',
#  'soy-tofu',
#  'spaghetti',
#  'spaghetti-sauce',
#  'spanish',
#  'spicy',
#  'spinach',
#  'spreads',
#  'spring',
#  'squash',
#  'squid',
#  'st-patricks-day',
#  'steak',
#  'steaks',
#  'steam',
#  'stews',
#  'stews-poultry',
#  'stir-fry',
#  'stocks',
#  'stove-top',
#  'strawberries',
#  'stuffings-dressings',
#  'sudanese',
#  'sugar-cookies',
#  'summer',
#  'super-bowl',
#  'superbowl',
#  'swedish',
#  'sweet',
#  'sweet-sauces',
#  'swiss',
#  'szechuan',
#  'tarts',
#  'taste-mood',
#  'technique',
#  'tempeh',
#  'tex-mex',
#  'thai',
#  'thanksgiving',
#  'tilapia',
#  'time-to-make',
#  'to-go',
#  'toddler-friendly',
#  'tomatoes',
#  'tropical-fruit',
#  'trout',
#  'tuna',
#  'turkey',
#  'turkey-breasts',
#  'turkey-burgers',
#  'turkish',
#  'unprocessed-freezer',
#  'valentines-day',
#  'veal',
#  'vegan',
#  'vegetables',
#  'vegetarian',
#  'veggie-burgers',
#  'venezuelan',
#  'very-low-carbs',
#  'vietnamese',
#  'water-bath',
#  'wedding',
#  'weeknight',
#  'welsh',
#  'white-rice',
#  'whitefish',
#  'whole-chicken',
#  'whole-duck',
#  'whole-turkey',
#  'wild-game',
#  'wings',
#  'winter',
#  'yams-sweet-potatoes',
#  'yeast',
#  'zucchini']

# %% [markdown]
# #### Extract `Meal Types` from the Tags

# %%
# Check the tags for meal types
meal_types = ["breakfast", "lunch", "dinner"]
for meal in meal_types:
    if meal in unique_tags:
        print(f"{meal} is a tag.")
    else:
        print(f"{meal} is not a tag.")

# Look for a similar tag to "dinner"
found = False
for tag in unique_tags:
    if (tag[:6] == "dinner"):
        print(f"{tag} is a match.")
        found = True
if (found is False):
    print("No matches found.")
# Out:
# breakfast is a tag.
# lunch is a tag.
# dinner is not a tag.
# dinner-party is a match.

# %%
# Count how many rows contain each meal type
updated_meals = ["breakfast", "lunch", "dinner-party"]

break_count = 0
lunch_count = 0
dinner_count = 0
multiple = 0
total = 0

break_list = []
lunch_list = []
dinner_list = []
multiple_list = []

for idx, string in merged_food.iterrows():
    # Strip and split the string to a list
    tag_list = string['tags'].strip("[]").split(', ')

    # Score tracks mutual exclusivity of the meal types
    score = 0
    # Get each tag from the list and categorise
    for word_idx in range(len(tag_list)):


        # Check the tag
        tag = tag_list[word_idx].strip("'")
        if (tag in updated_meals):
            total += 1
            if (tag == "breakfast"):
                break_list.append(idx)
                break_count += 1
                score += 1
            if (tag == "lunch"):
                lunch_list.append(idx)
                lunch_count += 1
                score += 1
            if (tag == "dinner-party"):
                dinner_list.append(idx)
                dinner_count += 1
                score += 1
            if (score > 1):
                multiple += 1
                multiple_list.append(idx)
                continue

combined_count = break_count + lunch_count + dinner_count
combined_list = break_list + lunch_list + dinner_list
overlap = (total == combined_count)
if (overlap is True):
    conclusion = "Recipes exist in more than one meal type."
elif (overlap is False):
    conclusion = "Recipes belong to only one meal type."

# Print findings
print(f"Total recipes with at least one tag: {total}")
print(32*'*')
print(f"Breakfast: {break_count}")
print(f"Lunch: {lunch_count}")
print(f"Dinner: {dinner_count}")
print(32*'*')
print(f"Multiple: {multiple}")
print(f"Checksum: {combined_count}")
print(f"Overlap? {overlap}. {conclusion}")
# Out:
# Total recipes with at least one tag: 73641
# ********************************
# Breakfast: 13375
# Lunch: 23392
# Dinner: 36874
# ********************************
# Multiple: 6879
# Checksum: 73641
# Overlap? True. Recipes exist in more than one meal type.

# %%
multiples_df = merged_food.iloc[multiple_list]
multiples_df['tags'][105]
# Out:
# "['time-to-make', 'course', 'preparation', 'occasion', 'appetizers', 'lunch', 'dinner-party', 'holiday-event', 'dietary', 'sandwiches', 'brunch']"

# %%
updated_merged = merged_food.iloc[combined_list]
# updated_merged.shape # only recipes with breakfast, lunch, or dinner
updated_merged.shape # (73641, 20)

# delete recipes with multiples
updated_merged = updated_merged.drop(multiple_list)
updated_merged.shape
# Out:
# (60009, 20)

# %%
test_df = merged_food.iloc[break_list]
subset = test_df[['rating', 'n_ingredients']]
subset.plot(kind="scatter", x='rating', y='n_ingredients')
# Higher ratings, less ingredients for breakfast.
# Out:
# <Axes: xlabel='rating', ylabel='n_ingredients'>

# %%
test2_df = merged_food.iloc[combined_list]
# subset2 = test2_df[['n_steps', 'Calories']]
# subset2
# subset2.plot(kind="scatter", x="n_steps", y="Calories")
# print(test2_df.shape)
test2_df.plot(kind="scatter", x="n_steps", y="Calories")
# Out:
# <Axes: xlabel='n_steps', ylabel='Calories'>

# %%
combined_list
# Out:
# [1,
#  9,
#  52,
#  53,
#  80,
#  131,
#  144,
#  147,
#  148,
#  150,
#  174,
#  195,
#  222,
#  249,
#  258,
#  274,
#  280,
#  298,
#  309,
#  312,
#  318,
#  359,
#  360,
#  373,
#  376,
#  386,
#  431,
#  441,
#  447,
#  455,
#  466,
#  476,
#  477,
#  542,
#  565,
#  581,
#  594,
#  596,
#  602,
#  618,
#  634,
#  657,
#  658,
#  663,
#  681,
#  703,
#  705,
#  720,
#  747,
#  762,
#  771,
#  834,
#  835,
#  841,
#  843,
#  856,
#  865,
#  868,
#  872,
#  873,
#  968,
#  976,
#  1022,
#  1050,
#  1057,
#  1072,
#  1088,
#  1094,
#  1111,
#  1117,
#  1131,
#  1132,
#  1213,
#  1224,
#  1236,
#  1290,
#  1303,
#  1364,
#  1389,
#  1416,
#  1449,
#  1456,
#  1469,
#  1510,
#  1548,
#  1564,
#  1570,
#  1632,
#  1638,
#  1641,
#  1642,
#  1643,
#  1692,
#  1728,
#  1768,
#  1778,
#  1809,
#  1822,
#  1828,
#  1851,
#  1852,
#  1856,
#  1870,
#  1877,
#  1883,
#  1884,
#  1897,
#  1903,
#  1997,
#  2021,
#  2068,
#  2105,
#  2114,
#  2144,
#  2172,
#  2178,
#  2181,
#  2198,
#  2208,
#  2210,
#  2229,
#  2244,
#  2248,
#  2255,
#  2260,
#  2382,
#  2423,
#  2437,
#  2441,
#  2463,
#  2478,
#  2575,
#  2577,
#  2578,
#  2579,
#  2589,
#  2603,
#  2626,
#  2653,
#  2747,
#  2749,
#  2773,
#  2845,
#  2900,
#  2902,
#  2924,
#  2928,
#  2935,
#  2974,
#  3035,
#  3137,
#  3185,
#  3195,
#  3221,
#  3223,
#  3245,
#  3246,
#  3256,
#  3267,
#  3293,
#  3307,
#  3313,
#  3319,
#  3320,
#  3322,
#  3332,
#  3334,
#  3338,
#  3349,
#  3372,
#  3415,
#  3435,
#  3468,
#  3470,
#  3480,
#  3481,
#  3494,
#  3503,
#  3515,
#  3529,
#  3559,
#  3592,
#  3618,
#  3628,
#  3629,
#  3637,
#  3638,
#  3639,
#  3640,
#  3645,
#  3649,
#  3655,
#  3656,
#  3663,
#  3695,
#  3727,
#  3730,
#  3738,
#  3739,
#  3740,
#  3745,
#  3774,
#  3775,
#  3780,
#  3788,
#  3807,
#  3824,
#  3854,
#  3867,
#  3872,
#  3891,
#  3899,
#  3900,
#  3901,
#  3909,
#  3916,
#  3925,
#  3929,
#  3949,
#  3965,
#  3986,
#  4040,
#  4049,
#  4050,
#  4061,
#  4111,
#  4119,
#  4120,
#  4135,
#  4148,
#  4181,
#  4191,
#  4203,
#  4205,
#  4222,
#  4233,
#  4252,
#  4258,
#  4274,
#  4275,
#  4277,
#  4308,
#  4311,
#  4345,
#  4346,
#  4358,
#  4367,
#  4423,
#  4433,
#  4434,
#  4454,
#  4455,
#  4456,
#  4487,
#  4488,
#  4510,
#  4528,
#  4537,
#  4543,
#  4547,
#  4548,
#  4602,
#  4656,
#  4675,
#  4693,
#  4728,
#  4729,
#  4766,
#  4776,
#  4780,
#  4787,
#  4800,
#  4826,
#  4866,
#  4873,
#  4902,
#  4920,
#  4921,
#  4924,
#  4925,
#  4927,
#  4951,
#  4965,
#  4966,
#  4978,
#  4980,
#  4997,
#  5002,
#  5004,
#  5005,
#  5019,
#  5021,
#  5094,
#  5119,
#  5121,
#  5141,
#  5148,
#  5170,
#  5178,
#  5181,
#  5187,
#  5239,
#  5329,
#  5364,
#  5385,
#  5457,
#  5467,
#  5487,
#  5491,
#  5492,
#  5494,
#  5498,
#  5503,
#  5559,
#  5573,
#  5582,
#  5598,
#  5632,
#  5633,
#  5646,
#  5660,
#  5674,
#  5782,
#  5785,
#  5789,
#  5792,
#  5794,
#  5811,
#  5822,
#  5825,
#  5826,
#  5849,
#  5860,
#  5867,
#  5868,
#  5894,
#  5907,
#  5918,
#  5920,
#  5930,
#  5931,
#  5940,
#  5941,
#  5942,
#  5944,
#  5962,
#  5973,
#  5986,
#  5999,
#  6009,
#  6016,
#  6029,
#  6036,
#  6049,
#  6053,
#  6054,
#  6058,
#  6072,
#  6074,
#  6089,
#  6100,
#  6103,
#  6104,
#  6107,
#  6109,
#  6112,
#  6118,
#  6123,
#  6124,
#  6142,
#  6143,
#  6144,
#  6145,
#  6147,
#  6149,
#  6177,
#  6180,
#  6187,
#  6188,
#  6215,
#  6251,
#  6261,
#  6268,
#  6278,
#  6331,
#  6332,
#  6343,
#  6344,
#  6345,
#  6361,
#  6363,
#  6364,
#  6367,
#  6370,
#  6373,
#  6378,
#  6379,
#  6380,
#  6382,
#  6384,
#  6385,
#  6386,
#  6388,
#  6389,
#  6391,
#  6392,
#  6393,
#  6394,
#  6395,
#  6398,
#  6399,
#  6404,
#  6406,
#  6407,
#  6413,
#  6414,
#  6415,
#  6416,
#  6427,
#  6440,
#  6457,
#  6467,
#  6468,
#  6473,
#  6479,
#  6481,
#  6490,
#  6504,
#  6513,
#  6515,
#  6519,
#  6542,
#  6548,
#  6556,
#  6560,
#  6561,
#  6564,
#  6576,
#  6582,
#  6583,
#  6595,
#  6597,
#  6602,
#  6612,
#  6620,
#  6621,
#  6625,
#  6627,
#  6639,
#  6654,
#  6666,
#  6667,
#  6668,
#  6669,
#  6670,
#  6676,
#  6681,
#  6712,
#  6717,
#  6732,
#  6745,
#  6758,
#  6762,
#  6767,
#  6771,
#  6774,
#  6775,
#  6776,
#  6777,
#  6778,
#  6781,
#  6789,
#  6790,
#  6795,
#  6805,
#  6811,
#  6814,
#  6815,
#  6816,
#  6817,
#  6818,
#  6819,
#  6820,
#  6821,
#  6823,
#  6830,
#  6833,
#  6845,
#  6851,
#  6854,
#  6857,
#  6884,
#  6891,
#  6893,
#  6907,
#  6908,
#  6921,
#  6924,
#  6934,
#  6935,
#  6936,
#  6940,
#  6974,
#  6975,
#  6978,
#  7001,
#  7003,
#  7004,
#  7005,
#  7013,
#  7047,
#  7048,
#  7072,
#  7075,
#  7079,
#  7080,
#  7081,
#  7082,
#  7084,
#  7085,
#  7087,
#  7112,
#  7131,
#  7133,
#  7144,
#  7147,
#  7148,
#  7151,
#  7157,
#  7159,
#  7165,
#  7171,
#  7177,
#  7190,
#  7213,
#  7217,
#  7234,
#  7238,
#  7239,
#  7244,
#  7249,
#  7251,
#  7252,
#  7253,
#  7270,
#  7286,
#  7290,
#  7291,
#  7293,
#  7296,
#  7300,
#  7302,
#  7307,
#  7322,
#  7332,
#  7336,
#  7338,
#  7340,
#  7347,
#  7360,
#  7368,
#  7382,
#  7389,
#  7392,
#  7395,
#  7397,
#  7398,
#  7402,
#  7407,
#  7408,
#  7415,
#  7420,
#  7429,
#  7438,
#  7442,
#  7446,
#  7455,
#  7464,
#  7466,
#  7471,
#  7476,
#  7483,
#  7484,
#  7488,
#  7492,
#  7494,
#  7497,
#  7508,
#  7568,
#  7573,
#  7583,
#  7586,
#  7599,
#  7612,
#  7613,
#  7617,
#  7621,
#  7629,
#  7640,
#  7647,
#  7650,
#  7655,
#  7673,
#  7674,
#  7677,
#  7681,
#  7682,
#  7685,
#  7691,
#  7696,
#  7700,
#  7702,
#  7703,
#  7704,
#  7711,
#  7716,
#  7722,
#  7723,
#  7725,
#  7745,
#  7746,
#  7762,
#  7763,
#  7778,
#  7804,
#  7805,
#  7821,
#  7831,
#  7832,
#  7905,
#  7932,
#  7936,
#  7941,
#  7964,
#  7977,
#  7979,
#  7996,
#  8001,
#  8015,
#  8031,
#  8065,
#  8066,
#  8068,
#  8076,
#  8084,
#  8085,
#  8089,
#  8090,
#  8093,
#  8096,
#  8103,
#  8138,
#  8142,
#  8146,
#  8158,
#  8186,
#  8206,
#  8227,
#  8286,
#  8313,
#  8316,
#  8364,
#  8451,
#  8452,
#  8529,
#  8545,
#  8558,
#  8562,
#  8565,
#  8578,
#  8582,
#  8588,
#  8616,
#  8629,
#  8647,
#  8681,
#  8687,
#  8692,
#  8711,
#  8769,
#  8805,
#  8809,
#  8817,
#  8846,
#  8852,
#  8878,
#  9193,
#  9226,
#  9431,
#  9442,
#  9450,
#  9452,
#  9456,
#  9479,
#  9480,
#  9486,
#  9487,
#  9489,
#  9499,
#  9500,
#  9519,
#  9525,
#  9526,
#  9554,
#  9575,
#  9588,
#  9607,
#  9611,
#  9614,
#  9640,
#  9656,
#  9672,
#  9723,
#  9825,
#  9837,
#  9876,
#  9887,
#  9902,
#  9940,
#  9967,
#  9975,
#  10074,
#  10090,
#  10095,
#  10097,
#  10111,
#  10130,
#  10145,
#  10186,
#  10197,
#  10273,
#  10301,
#  10307,
#  10308,
#  10321,
#  10331,
#  10332,
#  10334,
#  10371,
#  10387,
#  10404,
#  10449,
#  10450,
#  10540,
#  10581,
#  10639,
#  10675,
#  10705,
#  10706,
#  10721,
#  10727,
#  10728,
#  10751,
#  10846,
#  10859,
#  10864,
#  10865,
#  10871,
#  10923,
#  10940,
#  10983,
#  10985,
#  10988,
#  11055,
#  11058,
#  11078,
#  11088,
#  11161,
#  11189,
#  11203,
#  11207,
#  11212,
#  11248,
#  11249,
#  11250,
#  11252,
#  11258,
#  11313,
#  11366,
#  11388,
#  11402,
#  11419,
#  11426,
#  11464,
#  11487,
#  11505,
#  11517,
#  11521,
#  11551,
#  11634,
#  11672,
#  11673,
#  11675,
#  11677,
#  11721,
#  11808,
#  11856,
#  11859,
#  11868,
#  11881,
#  11884,
#  11885,
#  11886,
#  11890,
#  11893,
#  11894,
#  11895,
#  11898,
#  11899,
#  11901,
#  11912,
#  11915,
#  11916,
#  11923,
#  11940,
#  11945,
#  11953,
#  11956,
#  11957,
#  11959,
#  11960,
#  11966,
#  11967,
#  11971,
#  11975,
#  11978,
#  11981,
#  11983,
#  11984,
#  11987,
#  11988,
#  11989,
#  11990,
#  11991,
#  11992,
#  11993,
#  11994,
#  11996,
#  11997,
#  11999,
#  12002,
#  12003,
#  12005,
#  12006,
#  12007,
#  12008,
#  12009,
#  12010,
#  12011,
#  12013,
#  12015,
#  12023,
#  12039,
#  12040,
#  12041,
#  12047,
#  12049,
#  12062,
#  12064,
#  12076,
#  12080,
#  12083,
#  12085,
#  12091,
#  12100,
#  12102,
#  12106,
#  12107,
#  12108,
#  12109,
#  12120,
#  12123,
#  12126,
#  12131,
#  12133,
#  12135,
#  12143,
#  12147,
#  12151,
#  12155,
#  12158,
#  12163,
#  12184,
#  12216,
#  12223,
#  12235,
#  12236,
#  12239,
#  12245,
#  12251,
#  12252,
#  12256,
#  12257,
#  12263,
#  12290,
#  12295,
#  12307,
#  12309,
#  12334,
#  12335,
#  12339,
#  12342,
#  12351,
#  12361,
#  12368,
#  12378,
#  12387,
#  12388,
#  12389,
#  12391,
#  12392,
#  12393,
#  12394,
#  12492,
#  12495,
#  12507,
#  12512,
#  12516,
#  12517,
#  12519,
#  12520,
#  12521,
#  12522,
#  12523,
#  12525,
#  12526,
#  12527,
#  12528,
#  12531,
#  12533,
#  12544,
#  12546,
#  12549,
#  12555,
#  12563,
#  12571,
#  12573,
#  12581,
#  12589,
#  12603,
#  12612,
#  12624,
#  12710,
#  12715,
#  12717,
#  12718,
#  12719,
#  12720,
#  12721,
#  12722,
#  12725,
#  12727,
#  12728,
#  12732,
#  12759,
#  12761,
#  12837,
#  12871,
#  12898,
#  12923,
#  12952,
#  12953,
#  12955,
#  12962,
#  12994,
#  12999,
#  13000,
#  13010,
#  13011,
#  13012,
#  13015,
#  13016,
#  13017,
#  13018,
#  13024,
#  13031,
#  13037,
#  13061,
#  13075,
#  13109,
#  13113,
#  13117,
#  13120,
#  13123,
#  13161,
#  13235,
#  13238,
#  13243,
#  13244,
#  13246,
#  13264,
#  13265,
#  13266,
#  13267,
#  13290,
#  13295,
#  13316,
#  13349,
#  13353,
#  13384,
#  ...]

# %% [markdown]
# #### Extract `Cuisines` from the Tags

# %%
input_string = input("List to pass: ")


spoonacular_cuisines = input_string.split(' ')
spoonacular_cuisines = [word.lower() for word in spoonacular_cuisines]
spoonacular_cuisines # DOES NOT ACCOUNT FOR DOUBLE WORD.

# List comprehension to remove double words
double_words = ['eastern', 'european', 'latin', 'american', 'middle']
[spoonacular_cuisines.remove(word) for word in double_words]

# Return the two-word cuisines
spoonacular_cuisines += ['eastern european', 'latin american', 'middle eastern']
spoonacular_cuisines = sorted(spoonacular_cuisines)
# Out:
# List to pass:  African Asian American British Cajun Caribbean Chinese Eastern European European French German Greek Indian Irish Italian Japanese Jewish Korean Latin American Mediterranean Mexican Middle Eastern Nordic Southern Spanish Thai Vietnamese

# %%
# Search for matches with FOOD.COM tags
cuisine_match = []
cuisine_mismatch = []
for cuisine in spoonacular_cuisines:
    if cuisine in unique_tags:
        cuisine_match.append(cuisine)
    else:
        cuisine_mismatch.append(cuisine)
print(f"Cuisine match: ({len(cuisine_match)}), {cuisine_match}")
print(f"Cuisine mismatch: ({len(cuisine_mismatch)}), {cuisine_mismatch}")
# Out:
# Cuisine match: (19), ['african', 'american', 'asian', 'cajun', 'caribbean', 'chinese', 'european', 'french', 'german', 'greek', 'indian', 'irish', 'italian', 'japanese', 'korean', 'mexican', 'spanish', 'thai', 'vietnamese']
# Cuisine mismatch: (9), ['british', 'eastern', 'eastern european', 'jewish', 'latin american', 'mediterranean', 'middle eastern', 'nordic', 'southern']

# %%
updated_merged.head()
# Out:
#                                     name     id  minutes  contributor_id  \
# 1       a bit different  breakfast pizza  31490       30           26278
# 9                beat this  banana bread  75452       70           15892
# 52                kitchen sink  egg bake  59632       70           79219
# 53            land of nod  cinnamon buns  22526       35           29212
# 80  rise and shine  german fruit pancake  71457       45           93698
#
#      submitted                                               tags  \
# 1   2002-06-17  ['30-minutes-or-less', 'time-to-make', 'course...
# 9   2003-11-04  ['weeknight', 'time-to-make', 'course', 'main-...
# 52  2003-04-14  ['weeknight', 'time-to-make', 'course', 'main-...
# 53  2002-03-14  ['60-minutes-or-less', 'time-to-make', 'course...
# 80  2003-09-15  ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                             nutrition  n_steps  \
# 1           [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 9   [2669.3, 160.0, 976.0, 107.0, 62.0, 310.0, 138.0]       12
# 52        [794.2, 109.0, 9.0, 30.0, 59.0, 153.0, 3.0]       14
# 53       [575.3, 18.0, 116.0, 34.0, 28.0, 22.0, 34.0]        7
# 80        [253.0, 13.0, 64.0, 10.0, 11.0, 16.0, 13.0]       11
#
#                                                 steps  \
# 1   ['preheat oven to 425 degrees f', 'press dough...
# 9   ['preheat oven to 350 degrees', 'butter two 9x...
# 52  ['preheat oven to 325', 'thaw spinach , and sq...
# 53  ['before you turn in for the night , grease a ...
# 80  ['preheat oven to 450 degrees', 'with an elect...
#
#                                           description  \
# 1   this recipe calls for the crust to be prebaked...
# 9                                 from ann hodgman's
# 52                                       i call this
# 53  i have made this several times and it's dead e...
# 80  source: kbyu's culinary creations with mary cr...
#
#                                           ingredients  n_ingredients  \
# 1   ['prepared pizza crust', 'sausage patty', 'egg...              6
# 9   ['sugar', 'unsalted butter', 'bananas', 'eggs'...              9
# 52  ['eggs', 'cottage cheese', 'cheese', 'frozen c...             11
# 53  ['rolls', 'brown sugar', 'instant vanilla pudd...              6
# 80  ['eggs', 'flour', 'milk', 'salt', 'butter', 'p...              8
#
#       rating  Calories  Total Fat (PDV)  Sugar (PDV)  Sodium (PDV)  \
# 1   4.666667     173.4             18.0          0.0          17.0
# 9   4.400000    2669.3            160.0        976.0         107.0
# 52  4.000000     794.2            109.0          9.0          30.0
# 53  4.734694     575.3             18.0        116.0          34.0
# 80  5.000000     253.0             13.0         64.0          10.0
#
#     Protein (PDV)  Saturated Fat (PDV)  Carbohydrates (PDV)
# 1            22.0                 35.0                  1.0
# 9            62.0                310.0                138.0
# 52           59.0                153.0                  3.0
# 53           28.0                 22.0                 34.0
# 80           11.0                 16.0                 13.0

# %%
total_cuisine = 0
multiple_cuisines = []
has_cuisine = []
for idx, string in updated_merged.iterrows():
    cuisines_list = string['tags'].strip("[]").split(', ')
    score = 0

    # checks every tag in the recipe
    for word_idx in range(len(cuisines_list)):
        cuisine = cuisines_list[word_idx].strip("'")
        if (cuisine in cuisine_match):
            # if (idx not in has_cuisine):
            #     has_cuisine.append(idx)
            total_cuisine += 1
            has_cuisine.append(string['id'])
            score += 1
    if (score > 1):
        multiple_cuisines.append(string['id'])

# Print findings
print(f"Total count of cuisines in the tags: {total_cuisine}")
print(f"Total cuisines with more than one: {len(multiple_cuisines)}")

# unique_cuisines = set(has_cuisine)
# Filter the DataFrame for cuisines with at least one
print(updated_merged.shape)

# Get recipes with at least one cuisine
cuisine_merged = updated_merged.loc[updated_merged['id'].isin(has_cuisine)]
cuisine_merged.shape

# Get recipes with only one cuisine
cuisine_merged = cuisine_merged.loc[~updated_merged['id'].isin(multiple_cuisines)]
cuisine_merged.shape
# print(len(unique_cuisines))
# cuisine_merged = updated_merged.iloc[has_cuisine]
# cuisine_merged
# max(updated_merged.index)
# Out:
# Total count of cuisines in the tags: 32927
# Total cuisines with more than one: 8327
# (60009, 20)
# (15260, 20)

# %%
cuisine_merged.plot(kind="scatter", x='n_steps', y='minutes')
# Out:
# <Axes: xlabel='n_steps', ylabel='minutes'>

# %%
minutes_min = cuisine_merged['minutes'].min()
minutes_max = cuisine_merged['minutes'].max()
minutes_mean = cuisine_merged['minutes'].mean()
minutes_median = cuisine_merged['minutes'].median()
minutes_mode = cuisine_merged['minutes'].mode()

print(f'Minutes min: {minutes_min}')
print(f'Minutes max: {minutes_max}')
print(f'Minutes mean: {minutes_mean}')
print(f'Minutes median: {minutes_median}')
print(f'Minutes mode: {minutes_mode}')

minutes_lower = cuisine_merged['minutes'].quantile(0.25)
minutes_upper = cuisine_merged['minutes'].quantile(0.75)
minutes_iqr = minutes_upper - minutes_lower
lower_bounds = minutes_lower - (1.5*minutes_iqr)
upper_bounds = minutes_upper + (1.5*minutes_iqr)
print(f'Minutes lower bounds: {lower_bounds}')
print(f'Minutes upper bounds: {upper_bounds}')
# Out:
# Minutes min: 0
# Minutes max: 201610
# Minutes mean: 104.41140235910878
# Minutes median: 35.0
# Minutes mode: 0    30
# Name: minutes, dtype: int64
# Minutes lower bounds: -47.5
# Minutes upper bounds: 132.5

# %%
# Remove results with minutes beyond the upper bounds
check = cuisine_merged.loc[cuisine_merged['minutes'] > upper_bounds]
print(len(check))

cuisine_merged = cuisine_merged.loc[cuisine_merged['minutes'] < upper_bounds]
# Out:
# 1392

# %%
ingredients_min = cuisine_merged['n_ingredients'].min()
ingredients_max = cuisine_merged['n_ingredients'].max()
ingredients_mean = cuisine_merged['n_ingredients'].mean()
ingredients_median = cuisine_merged['n_ingredients'].median()
ingredients_mode = cuisine_merged['n_ingredients'].mode()

print(f'Ingredients min: {ingredients_min}')
print(f'Ingredients max: {ingredients_max}')
print(f'Ingredients mean: {ingredients_mean}')
print(f'Ingredients median: {ingredients_median}')
print(f'Ingredients mode: {ingredients_mode}')

ingredients_lower = cuisine_merged['n_ingredients'].quantile(0.25)
ingredients_upper = cuisine_merged['n_ingredients'].quantile(0.75)
ingredients_iqr = ingredients_upper - ingredients_lower
lower_bounds = ingredients_lower - (1.5*ingredients_iqr)
upper_bounds = ingredients_upper + (1.5*ingredients_iqr)
print(f'Ingredients lower bounds: {lower_bounds}')
print(f'Ingredients upper bounds: {upper_bounds}')
# Out:
# Ingredients min: 2
# Ingredients max: 37
# Ingredients mean: 9.174214017882896
# Ingredients median: 9.0
# Ingredients mode: 0    8
# Name: n_ingredients, dtype: int64
# Ingredients lower bounds: -1.5
# Ingredients upper bounds: 18.5

# %%
# Remove results with number of ingredients beyond the upper bounds
check_ingredients = cuisine_merged.loc[cuisine_merged['n_ingredients'] > upper_bounds]
print(len(check_ingredients))

cuisine_merged = cuisine_merged.loc[cuisine_merged['n_ingredients'] < upper_bounds]
# Out:
# 281

# %%
cuisine_merged.plot(kind="scatter", x='n_steps', y='minutes')
# Out:
# <Axes: xlabel='n_steps', ylabel='minutes'>

# %%
cuisine_merged.plot(kind="scatter", x='Calories', y='n_ingredients')
# Out:
# <Axes: xlabel='Calories', ylabel='n_ingredients'>

# %%
calories_min = cuisine_merged['Calories'].min()
calories_max = cuisine_merged['Calories'].max()
calories_mean = cuisine_merged['Calories'].mean()
calories_median = cuisine_merged['Calories'].median()
calories_mode = cuisine_merged['Calories'].mode()

print(f'Calories min: {calories_min}')
print(f'Calories max: {calories_max}')
print(f'Calories mean: {calories_mean}')
print(f'Calories median: {calories_median}')
print(f'Calories mode: {calories_mode}')

calories_lower = cuisine_merged['Calories'].quantile(0.25)
calories_upper = cuisine_merged['Calories'].quantile(0.75)
calories_iqr = calories_upper - calories_lower
lower_bounds = calories_lower - (1.5*calories_iqr)
upper_bounds = calories_upper + (1.5*calories_iqr)
print(f'Calories lower bounds: {lower_bounds}')
print(f'Calories upper bounds: {upper_bounds}')
# Out:
# Calories min: 0.0
# Calories max: 13598.2
# Calories mean: 447.9301023036727
# Calories median: 323.6
# Calories mode: 0    103.3
# 1    234.3
# 2    253.0
# 3    258.7
# 4    261.9
# 5    291.5
# 6    332.4
# Name: Calories, dtype: float64
# Calories lower bounds: -305.2
# Calories upper bounds: 1005.1999999999999

# %%
# Remove results with number of ingredients beyond the upper bounds
check_calories = cuisine_merged.loc[cuisine_merged['Calories'] > upper_bounds]
print(len(check_calories))

cuisine_merged = cuisine_merged.loc[cuisine_merged['Calories'] < upper_bounds]
# Out:
# 790

# %%
cuisine_merged.shape
# Out:
# (12797, 20)

# %%
cuisine_merged.plot(kind="scatter", x='Calories', y='n_ingredients')
# Out:
# <Axes: xlabel='Calories', ylabel='n_ingredients'>

# %%
cuisine_sample = cuisine_merged.sample(n=1000)
cuisine_sample.plot(kind="scatter", x='Calories', y='n_ingredients')

x_values = cuisine_sample['Calories']
y_values = cuisine_sample['n_ingredients']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept

plt.plot(x_values, regression_values, color='red')
plt.show()

r_value = pearsonr(x_values, y_values)
print(f'R-value: {r_value[0]**2}')
print(f'P-value: {r_value[1]}')
print(r_value)
# Out:
# R-value: 0.07810449561394586
# P-value: 2.1237898634782427e-19
# PearsonRResult(statistic=0.2794718154196338, pvalue=2.1237898634782427e-19)

# %%
cuisine_sample = cuisine_merged.sample(n=1000)
cuisine_sample.plot(kind="scatter", x='rating', y='n_steps')
# Out:
# <Axes: xlabel='rating', ylabel='n_steps'>

# %%
steps_min = cuisine_merged['n_steps'].min()
steps_max = cuisine_merged['n_steps'].max()
steps_mean = cuisine_merged['n_steps'].mean()
steps_median = cuisine_merged['n_steps'].median()
steps_mode = cuisine_merged['n_steps'].mode()

print(f'Steps min: {steps_min}')
print(f'Steps max: {steps_max}')
print(f'Steps mean: {steps_mean}')
print(f'Steps median: {steps_median}')
print(f'Steps mode: {steps_mode}')

steps_lower = cuisine_merged['n_steps'].quantile(0.25)
steps_upper = cuisine_merged['n_steps'].quantile(0.75)
steps_iqr = steps_upper - steps_lower
lower_bounds = steps_lower - (1.5*steps_iqr)
upper_bounds = steps_upper + (1.5*steps_iqr)
print(f'Steps lower bounds: {lower_bounds}')
print(f'Steps upper bounds: {upper_bounds}')
# Out:
# Steps min: 1
# Steps max: 82
# Steps mean: 9.756739860904899
# Steps median: 9.0
# Steps mode: 0    7
# Name: n_steps, dtype: int64
# Steps lower bounds: -3.0
# Steps upper bounds: 21.0

# %%
# Remove results with number of ingredients beyond the upper bounds
check_steps = cuisine_merged.loc[cuisine_merged['n_steps'] > upper_bounds]
print(len(check_calories))

cuisine_merged = cuisine_merged.loc[cuisine_merged['n_steps'] < upper_bounds]
# Out:
# 790

# %%
cuisine_merged.shape
# Out:
# (12190, 20)

# %%
cuisine_sample = cuisine_merged.sample(n=1000)
cuisine_sample.plot(kind="scatter", x='rating', y='n_steps')

x_values = cuisine_sample['rating']
y_values = cuisine_sample['n_steps']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept

plt.plot(x_values, regression_values, color='red')
plt.show()

r_value = pearsonr(x_values, y_values)
print(f'R-value: {r_value[0]**2}')
print(f'P-value: {r_value[1]}')
print(r_value)
# No correlation
# Out:
# R-value: 0.0002687565344464824
# P-value: 0.6045952100811063
# PearsonRResult(statistic=0.016393795608292863, pvalue=0.6045952100811063)

# %%
cuisine_sample = cuisine_merged.sample(n=1000)
cuisine_sample.plot(kind="scatter", x='rating', y='Sugar (PDV)')

x_values = cuisine_sample['rating']
y_values = cuisine_sample['Sugar (PDV)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept

plt.plot(x_values, regression_values, color='red')
plt.show()

r_value = pearsonr(x_values, y_values)
print(f'R-value: {r_value[0]**2}')
print(f'P-value: {r_value[1]}')
print(r_value)
# No correlation
# Out:
# R-value: 0.0029345741583633417
# P-value: 0.0868644909330442
# PearsonRResult(statistic=-0.054171709944982736, pvalue=0.0868644909330442)

# %%
cuisine_merged
# Out:
#                                                      name      id  minutes  \
# 1                        a bit different  breakfast pizza   31490       30
# 80                   rise and shine  german fruit pancake   71457       45
# 131               blepandekager   danish   apple pancakes  503475       50
# 360                              elephant ear  dutch baby  368320       25
# 542        tummy crisis  dried apricot and muesli muffins  305987       40
# ...                                                   ...     ...      ...
# 226255                                zucchini parmigiana  180779       25
# 226359  zucchini stuffed with tomato  white beans  and...  493719       24
# 226377                              zucchini tomato salsa  321224       20
# 226516  zucchini  courgettes sauteed with sun dried to...  413205       40
# 226524         zucre coco    moroccan coconut fudge cakes  147306       35
#
#         contributor_id   submitted  \
# 1                26278  2002-06-17
# 80               93698  2003-09-15
# 131             128473  2013-07-08
# 360            1232400  2009-04-28
# 542             382071  2008-05-29
# ...                ...         ...
# 226255          232669  2006-08-07
# 226359          266635  2013-01-16
# 226377          464080  2008-08-25
# 226516          485109  2010-02-16
# 226524          230157  2005-12-05
#
#                                                      tags  \
# 1       ['30-minutes-or-less', 'time-to-make', 'course...
# 80      ['60-minutes-or-less', 'time-to-make', 'course...
# 131     ['danish', '60-minutes-or-less', 'time-to-make...
# 360     ['30-minutes-or-less', 'time-to-make', 'course...
# 542     ['60-minutes-or-less', 'time-to-make', 'course...
# ...                                                   ...
# 226255  ['30-minutes-or-less', 'time-to-make', 'course...
# 226359  ['weeknight', '30-minutes-or-less', 'time-to-m...
# 226377  ['30-minutes-or-less', 'time-to-make', 'course...
# 226516  ['weeknight', '60-minutes-or-less', 'time-to-m...
# 226524  ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                            nutrition  n_steps  \
# 1          [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 80       [253.0, 13.0, 64.0, 10.0, 11.0, 16.0, 13.0]       11
# 131      [358.2, 30.0, 62.0, 14.0, 19.0, 54.0, 12.0]       10
# 360      [552.2, 54.0, 53.0, 13.0, 36.0, 95.0, 13.0]        9
# 542     [389.3, 19.0, 132.0, 15.0, 15.0, 36.0, 21.0]       14
# ...                                              ...      ...
# 226255      [182.0, 7.0, 31.0, 20.0, 44.0, 5.0, 4.0]       12
# 226359     [305.7, 23.0, 23.0, 0.0, 24.0, 8.0, 11.0]        9
# 226377         [39.2, 0.0, 25.0, 3.0, 2.0, 0.0, 3.0]        4
# 226516        [115.4, 7.0, 33.0, 6.0, 8.0, 3.0, 5.0]       12
# 226524      [139.0, 14.0, 48.0, 0.0, 2.0, 39.0, 4.0]       11
#
#                                                     steps  \
# 1       ['preheat oven to 425 degrees f', 'press dough...
# 80      ['preheat oven to 450 degrees', 'with an elect...
# 131     ['beat the eggs lightly and add the milk', 'co...
# 360     ['preheat oven to 425', 'mix the eggs , flour ...
# 542     ['preheat oven to 350f grease 12 muffin tins a...
# ...                                                   ...
# 226255  ['preheat oven to 400f', 'heat oil in a heavy ...
# 226359  ['scoop out the zucchini flesh , keeping about...
# 226377  ['in a small bowl , combine the first 12 ingre...
# 226516  ['place the sundried tomatoes in the 3 / 4 cup...
# 226524  ['line an 8x8 pan or similar sized round pan w...
#
#                                               description  \
# 1       this recipe calls for the crust to be prebaked...
# 80      source: kbyu's culinary creations with mary cr...
# 131     this recipe has been posted here for play in z...
# 360     this recipe is so named because the cinnamon s...
# 542     from: "the africa kitchen by josie stow and ja...
# ...                                                   ...
# 226255  just a bit different but very good and tasty. ...
# 226359  this recipe will require a large cooker (prefe...
# 226377  a contest winner from taste of home.  it state...
# 226516  this is a lovely mediterranean side dish, and ...
# 226524  literally this translates into coconut sugar. ...
#
#                                               ingredients  n_ingredients  \
# 1       ['prepared pizza crust', 'sausage patty', 'egg...              6
# 80      ['eggs', 'flour', 'milk', 'salt', 'butter', 'p...              8
# 131     ['eggs', 'milk', 'flour', 'sugar', 'salt', 'cr...             10
# 360     ['butter', 'eggs', 'all-purpose flour', 'milk'...              5
# 542     ['brown sugar', 'muesli', 'butter', 'flour', '...             16
# ...                                                   ...            ...
# 226255  ['olive oil', 'garlic cloves', 'italian herb s...              7
# 226359  ['zucchini', 'olive oil', 'shallots', 'garlic ...             10
# 226377  ['chopped tomato', 'zucchini', 'red bell peppe...             13
# 226516  ['sun-dried tomatoes', 'warm water', 'olive oi...              8
# 226524  ['unsweetened coconut', 'evaporated milk', 'su...              5
#
#           rating  Calories  Total Fat (PDV)  Sugar (PDV)  Sodium (PDV)  \
# 1       4.666667     173.4             18.0          0.0          17.0
# 80      5.000000     253.0             13.0         64.0          10.0
# 131     5.000000     358.2             30.0         62.0          14.0
# 360     4.333333     552.2             54.0         53.0          13.0
# 542     3.000000     389.3             19.0        132.0          15.0
# ...          ...       ...              ...          ...           ...
# 226255  4.000000     182.0              7.0         31.0          20.0
# 226359  5.000000     305.7             23.0         23.0           0.0
# 226377  5.000000      39.2              0.0         25.0           3.0
# 226516  5.000000     115.4              7.0         33.0           6.0
# 226524  5.000000     139.0             14.0         48.0           0.0
#
#         Protein (PDV)  Saturated Fat (PDV)  Carbohydrates (PDV)
# 1                22.0                 35.0                  1.0
# 80               11.0                 16.0                 13.0
# 131              19.0                 54.0                 12.0
# 360              36.0                 95.0                 13.0
# 542              15.0                 36.0                 21.0
# ...               ...                  ...                  ...
# 226255           44.0                  5.0                  4.0
# 226359           24.0                  8.0                 11.0
# 226377            2.0                  0.0                  3.0
# 226516            8.0                  3.0                  5.0
# 226524            2.0                 39.0                  4.0
#
# [12190 rows x 20 columns]

# %% [markdown]
# ## Initial Data Exploration - SPOONACULAR API
# __Goal:__ Test the API, check returned format and attributes.
#
# __Process__
# 1. Get recipe IDs, these are needed to pass to other methods (i.e. `Recipe Information`).
# 2. Get recipe metadata using `Recipe Information`.
# 3. Save raw response to a CSV to minimise API request repetition.
#
# #### Parse API Response

# %% [markdown]
# ### Complex Search and Recipe Information
# - Complex Search: [https://spoonacular.com/food-api/docs#Search-Recipes-Complex](https://spoonacular.com/food-api/docs#Search-Recipes-Complex)
# - Recipe Information: [https://spoonacular.com/food-api/docs#Get-Recipe-Information](https://spoonacular.com/food-api/docs#Get-Recipe-Information)
#
# __OBSERVATIONS__
# - `Complex Search` returns the same result every time, need to try `Random Recipes`.

# %%
# API REQUEST - Complex Search.
recipe_url = "https://api.spoonacular.com/recipes/complexSearch"

# Set request parameters
recipe_params = {
    'apiKey': spoonacular_key,
    'number': 100}

# Request a list of recipes.
recipe_response = requests.get(recipe_url, recipe_params).json()

# Output response to a csv
recipes_df = pd.DataFrame(recipe_response['results'])
recipes_df.to_csv(f'Resources/01_recipe_IDs/initial_recipes_0.csv', index=False)

# %%
# Import and display complex search results
recipes_df = pd.read_csv(f'Resources/01_recipe_IDs/initial_recipes_0.csv')
recipes_df.head()
# Out:
#        id                                              title  \
# 0  782585  Cannellini Bean and Asparagus Salad with Mushr...
# 1  716426  Cauliflower, Brown Rice, and Vegetable Fried Rice
# 2  715497                    Berry Banana Breakfast Smoothie
# 3  715415           Red Lentil Soup with Chicken and Turnips
# 4  716406      Asparagus and Pea Soup: Real Convenience Food
#
#                                                image imageType
# 0  https://spoonacular.com/recipeImages/782585-31...       jpg
# 1  https://spoonacular.com/recipeImages/716426-31...       jpg
# 2  https://spoonacular.com/recipeImages/715497-31...       jpg
# 3  https://spoonacular.com/recipeImages/715415-31...       jpg
# 4  https://spoonacular.com/recipeImages/716406-31...       jpg

# %%
# Check the number of returned recipes
print(f'Number of recipes returned: {len(recipes_df)}')
# Out:
# Number of recipes returned: 100

# %%
# API REQUEST - Recipe Information
recipe_info = []
for id in recipes_df['id']:
    info_url = f"https://api.spoonacular.com/recipes/{id}/information?"
    info_params = {
        'apiKey': spoonacular_key,
        'includeNutrition': "true"}

    info_response = requests.get(info_url, info_params).json()
    recipe_info.append(info_response)

info_df = pd.DataFrame(recipe_info)
info_df.to_csv(f'Resources/02_raw_data/info_master_0.csv')

# %%
# While the API response is accessible, identify attributes of interest
recipe_info[0].keys()

# Generic metadata
recipe_info[0]['id']
recipe_info[0]['title']
recipe_info[0]['aggregateLikes'] # will need to convert this to a 5-point scale
recipe_info[0]['extendedIngredients'] # can use len() to get the number of ingredients
recipe_info[0]['weightWatcherSmartPoints'] # research the equation for this
recipe_info[0]['cuisines'] # identify recipes with non-empty results
recipe_info[0]['dishTypes'] # will need to select a simpler subset

# Nutritional values - amount, unit, percent of daily needs
recipe_info[0]['nutrition']['nutrients'][0] # Calories
recipe_info[0]['nutrition']['nutrients'][2] # Saturated Fat
recipe_info[0]['nutrition']['nutrients'][5] # Sugar
recipe_info[0]['nutrition']['nutrients'][7] # Sodium
recipe_info[0]['nutrition']['nutrients'][8] # Protein

# %%
# Import and display recipe information results
info_df = pd.read_csv(f'Resources/02_raw_data/info_master_0.csv')

# Get the list of column names
info_df.columns

# Display the dataframe
info_df.head()
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True        True       True         True  False        False
# 1        True   True        True       True         True  False         True
# 2        True  False       False      False         True  False         True
# 3       False  False        True       True         True  False         True
# 4        True   True        True       True         True  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...  \
# 0        False      False                        12  ...
# 1        False      False                         4  ...
# 2        False      False                        15  ...
# 3        False      False                        11  ...
# 4        False      False                         2  ...
#
#                                            dishTypes  \
# 0  ['side dish', 'lunch', 'main course', 'salad',...
# 1  ['side dish', 'antipasti', 'starter', 'snack',...
# 2  ['morning meal', 'brunch', 'beverage', 'breakf...
# 3  ['lunch', 'soup', 'main course', 'main dish', ...
# 4  ['antipasti', 'soup', 'starter', 'snack', 'app...
#
#                                                diets           occasions  \
# 0  ['gluten free', 'dairy free', 'lacto ovo veget...                  []
# 1  ['gluten free', 'dairy free', 'lacto ovo veget...                  []
# 2                           ['lacto ovo vegetarian']                  []
# 3                      ['gluten free', 'dairy free']  ['fall', 'winter']
# 4  ['gluten free', 'dairy free', 'paleolithic', '...  ['fall', 'winter']
#
#                                          winePairing  \
# 0  {'pairedWines': ['chardonnay', 'sauvignon blan...
# 1  {'pairedWines': ['wine', 'alcoholic drink', 'w...
# 2  {'pairedWines': [], 'pairingText': '', 'produc...
# 3  {'pairedWines': [], 'pairingText': '', 'produc...
# 4  {'pairedWines': ['sparkling wine', 'sparkling ...
#
#                                         instructions  \
# 0  Rinse the cannellini beans and soak for 8 hour...
# 1  <ol><li><span></span>Remove the cauliflower's ...
# 2  <p>Take some yogurt in your favorite flavor an...
# 3  To a large dutch oven or soup pot, heat the ol...
# 4  <ol><li><span></span>Chop the garlic and onion...
#
#                                 analyzedInstructions originalId  \
# 0  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 1  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 2  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 3  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 4  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
#
#                                 spoonacularSourceUrl       license  author
# 0  https://spoonacular.com/cannellini-bean-and-as...           NaN     NaN
# 1  https://spoonacular.com/cauliflower-brown-rice...  CC BY-SA 3.0     NaN
# 2  https://spoonacular.com/berry-banana-breakfast...           NaN     NaN
# 3  https://spoonacular.com/red-lentil-soup-with-c...           NaN     NaN
# 4  https://spoonacular.com/asparagus-and-pea-soup...  CC BY-SA 3.0     NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Random Recipes and Recipe Information
# - Random Recipes: [https://spoonacular.com/food-api/docs#Get-Random-Recipes](https://spoonacular.com/food-api/docs#Get-Random-Recipes)
# - Recipe Information: [https://spoonacular.com/food-api/docs#Get-Recipe-Information](https://spoonacular.com/food-api/docs#Get-Recipe-Information)
#
# __OBSERVATIONS__
# - Once converted to a dataframe, the data is not as accessible as navigating the API response, will need to create a simplified dataframe while the API response is available.
# - Although this has metadata, it still does not have `Nutrition` information, will still need to run the `Recipe Information` request. Need to identify a cost-effective API request methodology.

# %%
# API REQUEST - Random Recipe
random_url = "https://api.spoonacular.com/recipes/random?"

# Set request parameters
random_params = {
    'apiKey': spoonacular_key,
    'number': 100}

# Request a list of random recipe IDs.
random_response = requests.get(random_url, random_params).json()

# Output response to a csv
random_df = pd.DataFrame(random_response['recipes'])
random_df.to_csv(f'Resources/01_recipe_IDs/initial_recipes_4.csv', index=False)

# %%
# Import and display random recipes results
random_df = pd.read_csv(f'Resources/01_recipe_IDs/initial_recipes_4.csv')
random_df.head()
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False       False      False        False  False        False
# 1       False  False       False      False        False  False        False
# 2        True   True        True       True        False  False        False
# 3       False  False       False       True        False  False        False
# 4        True   True        True       True         True  False        False
#
#    sustainable  lowFodmap  weightWatcherSmartPoints  ...      cuisines  \
# 0        False      False                        28  ...  ['American']
# 1        False      False                        39  ...            []
# 2        False      False                         3  ...            []
# 3        False      False                        12  ...   ['Mexican']
# 4        False      False                         6  ...            []
#
#                                            dishTypes  \
# 0    ['lunch', 'main course', 'main dish', 'dinner']
# 1                                        ['dessert']
# 2  ['side dish', 'antipasti', 'salad', 'starter',...
# 3    ['lunch', 'main course', 'main dish', 'dinner']
# 4  ['lunch', 'soup', 'main course', 'main dish', ...
#
#                                                diets           occasions  \
# 0                                                 []                  []
# 1                                                 []                  []
# 2  ['gluten free', 'dairy free', 'paleolithic', '...       ['christmas']
# 3                      ['dairy free', 'pescatarian']                  []
# 4  ['gluten free', 'dairy free', 'lacto ovo veget...  ['fall', 'winter']
#
#                                         instructions  \
# 0  <ol><li>Preheat broiler. </li><li>Heat large f...
# 1  <ol><li>Preheat oven to 180 degrees C</li><li>...
# 2  Finely grate enough zest from the orange to me...
# 3  In pie pan/deep dish add your Italian bread cr...
# 4  <ol><li>Rinse the beans thoroughly and place t...
#
#                                 analyzedInstructions originalId  \
# 0  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 1  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 2  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 3  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 4  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
#
#                                 spoonacularSourceUrl    license  author
# 0      https://spoonacular.com/tex-mex-burger-663050        NaN     NaN
# 1  https://spoonacular.com/chocolate-banoffee-pie...  CC BY 3.0     NaN
# 2  https://spoonacular.com/fennel-and-orange-sala...  CC BY 3.0     NaN
# 3      https://spoonacular.com/kks-fish-tacos-648974        NaN     NaN
# 4  https://spoonacular.com/tuscan-white-bean-soup...        NaN     NaN
#
# [5 rows x 37 columns]

# %%
# Get the list of column name
random_df.columns
# Out:
# Index(['vegetarian', 'vegan', 'glutenFree', 'dairyFree', 'veryHealthy',
#        'cheap', 'veryPopular', 'sustainable', 'lowFodmap',
#        'weightWatcherSmartPoints', 'gaps', 'preparationMinutes',
#        'cookingMinutes', 'aggregateLikes', 'healthScore', 'creditsText',
#        'sourceName', 'pricePerServing', 'extendedIngredients', 'id', 'title',
#        'readyInMinutes', 'servings', 'sourceUrl', 'image', 'imageType',
#        'summary', 'cuisines', 'dishTypes', 'diets', 'occasions',
#        'instructions', 'analyzedInstructions', 'originalId',
#        'spoonacularSourceUrl', 'license', 'author'],
#       dtype='object')

# %%
# API REQUEST - Recipe Information
recipe_info = []
for id in random_df['id']:
    info_url = f"https://api.spoonacular.com/recipes/{id}/information?"
    info_params = {
        'apiKey': spoonacular_key,
        'includeNutrition': "true"}

    info_response = requests.get(info_url, info_params).json()
    recipe_info.append(info_response)

info_df = pd.DataFrame(recipe_info)
info_df.to_csv(f'Resources/02_raw_data/info_master_4.csv')

# %%
# Display the dataframe\
info_df.head()
# Out:
#    Unnamed: 0  vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  \
# 0           0       False  False       False      False        False  False
# 1           1       False  False       False      False        False  False
# 2           2        True   True        True       True        False  False
# 3           3       False  False       False       True        False  False
# 4           4        True   True        True       True         True  False
#
#    veryPopular  sustainable  lowFodmap  ...  \
# 0        False        False      False  ...
# 1        False        False      False  ...
# 2        False        False      False  ...
# 3        False        False      False  ...
# 4        False        False      False  ...
#
#                                            dishTypes  \
# 0    ['lunch', 'main course', 'main dish', 'dinner']
# 1                                        ['dessert']
# 2  ['side dish', 'antipasti', 'salad', 'starter',...
# 3    ['lunch', 'main course', 'main dish', 'dinner']
# 4  ['lunch', 'soup', 'main course', 'main dish', ...
#
#                                                diets           occasions  \
# 0                                                 []                  []
# 1                                                 []                  []
# 2  ['gluten free', 'dairy free', 'paleolithic', '...       ['christmas']
# 3                      ['dairy free', 'pescatarian']                  []
# 4  ['gluten free', 'dairy free', 'lacto ovo veget...  ['fall', 'winter']
#
#                                          winePairing  \
# 0  {'pairedWines': ['merlot', 'malbec', 'zinfande...
# 1  {'pairedWines': ['vin santo', 'late harvest ri...
# 2  {'pairedWines': ['chardonnay', 'sauvignon blan...
# 3  {'pairedWines': ['pinot noir', 'pinot grigio',...
# 4  {'pairedWines': [], 'pairingText': '', 'produc...
#
#                                         instructions  \
# 0  <ol><li>Preheat broiler. </li><li>Heat large f...
# 1  <ol><li>Preheat oven to 180 degrees C</li><li>...
# 2  Finely grate enough zest from the orange to me...
# 3  In pie pan/deep dish add your Italian bread cr...
# 4  <ol><li>Rinse the beans thoroughly and place t...
#
#                                 analyzedInstructions originalId  \
# 0  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 1  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 2  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 3  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
# 4  [{'name': '', 'steps': [{'number': 1, 'step': ...        NaN
#
#                                 spoonacularSourceUrl    license author
# 0      https://spoonacular.com/tex-mex-burger-663050        NaN    NaN
# 1  https://spoonacular.com/chocolate-banoffee-pie...  CC BY 3.0    NaN
# 2  https://spoonacular.com/fennel-and-orange-sala...  CC BY 3.0    NaN
# 3      https://spoonacular.com/kks-fish-tacos-648974        NaN    NaN
# 4  https://spoonacular.com/tuscan-white-bean-soup...        NaN    NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Parse API Response
#
# __OBSERVATIONS__
# - Ensure all relevant columns are accounted for before bulk requesting.
# - Will need to account for different units.

# %%
# Metadata
recipe_id = []
recipe_name = []
recipe_likes = []
meal_type = []
cuisines = []
num_ingredients = []
ww_points = []

# Calories
calories_amt = []
calories_unit = []
calories_pct = []

# Saturated Fat
satfat_amt = []
satfat_unit = []
satfat_pct = []

# Sugar
sugar_amt = []
sugar_unit = []
sugar_pct = []

# Sodium
sodium_amt = []
sodium_unit = []
sodium_pct = []

# Protein
protein_amt = []
protein_unit = []
protein_pct = []

for idx, row in enumerate(recipe_info):
    try:
        recipe_id.append(recipe_info[idx]['id'])
        recipe_name.append(recipe_info[idx]['title'])
        recipe_likes.append(recipe_info[idx]['aggregateLikes'])
        meal_type.append(recipe_info[idx]['dishTypes'])
        cuisines.append(recipe_info[idx]['cuisines'])
        num_ingredients.append(len(recipe_info[idx]['extendedIngredients']))
        ww_points.append(recipe_info[idx]['weightWatcherSmartPoints'])
        
        calories_amt.append(recipe_info[idx]['nutrition']['nutrients'][0]['amount'])
        calories_unit.append(recipe_info[idx]['nutrition']['nutrients'][0]['unit'])
        calories_pct.append(recipe_info[idx]['nutrition']['nutrients'][0]['percentOfDailyNeeds'])
        
        satfat_amt.append(recipe_info[idx]['nutrition']['nutrients'][2]['amount'])
        satfat_unit.append(recipe_info[idx]['nutrition']['nutrients'][2]['unit'])
        satfat_pct.append(recipe_info[idx]['nutrition']['nutrients'][2]['percentOfDailyNeeds'])
        
        sugar_amt.append(recipe_info[idx]['nutrition']['nutrients'][5]['amount'])
        sugar_unit.append(recipe_info[idx]['nutrition']['nutrients'][5]['unit'])
        sugar_pct.append(recipe_info[idx]['nutrition']['nutrients'][5]['percentOfDailyNeeds'])
        
        sodium_amt.append(recipe_info[idx]['nutrition']['nutrients'][7]['amount'])
        sodium_unit.append(recipe_info[idx]['nutrition']['nutrients'][7]['unit'])
        sodium_pct.append(recipe_info[idx]['nutrition']['nutrients'][7]['percentOfDailyNeeds'])
        
        protein_amt.append(recipe_info[idx]['nutrition']['nutrients'][8]['amount'])
        protein_unit.append(recipe_info[idx]['nutrition']['nutrients'][8]['unit'])
        protein_pct.append(recipe_info[idx]['nutrition']['nutrients'][8]['percentOfDailyNeeds'])
    
    except:
        print(idx)

spoonacular_df = pd.DataFrame({
    'ID': recipe_id,
    'Name': recipe_name,
    'Likes': recipe_likes,
    'Meal Type': meal_type,
    'Cuisines': cuisines,
    'N_ingredients': num_ingredients,
    'WW Smart Points': ww_points,
    'Calories (Amount)': calories_amt,
    'Calories (Unit)': calories_unit,
    'Calories (% of Daily Needs)': calories_pct,
    'Saturated Fat (Amount)': satfat_amt,
    'Saturated Fat (Unit)': satfat_unit,
    'Saturated Fat (% of Daily Needs)': satfat_pct,
    'Sugar (Amount)': sugar_amt,
    'Sugar (Unit)': sugar_unit,
    'Sugar (% of Daily Needs)': sugar_pct,
    'Sodium (Amount)': sodium_amt,
    'Sodium (Unit)': sodium_unit,
    'Sodium (% of Daily Needs)': sodium_pct,
    'Protein (Amount)': protein_amt,
    'Protein (Unit)': protein_unit,
    'Protein (% of Daily Needs)': protein_pct})

spoonacular_df.to_csv(f"Resources/03_simplified_data/initial_nutrition_4.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 35
#      32 protein_unit = []
#      33 protein_pct = []
# ---> 35 for idx, row in enumerate(recipe_info):
#      36     try:
#      37         recipe_id.append(recipe_info[idx]['id'])
#
# NameError: name 'recipe_info' is not defined

# %%
# Check the units columns
units_columns = ['Calories (Unit)', 'Saturated Fat (Unit)', 'Sugar (Unit)', 'Sodium (Unit)', 'Protein (Unit)']
for col in units_columns:
    check = spoonacular_df['Protein (Unit)'].unique()
    print(f"Unit check: {col} {check}")

# %% [markdown]
# ### Random Recipes and Nutrition by ID

# %%
# API REQUEST - Random Recipe
random_url = "https://api.spoonacular.com/recipes/random?"

# Set request parameters
random_params = {
    'apiKey': spoonacular_key,
    'number': 100}

# Request a list of random recipe IDs.
random_response = requests.get(random_url, random_params).json()

# Output response to a csv
random_df = pd.DataFrame(random_response['recipes'])
random_df.to_csv('Resources/01_recipe_IDs/initial_recipes_5.csv', index=False)

# %%
# API REQUEST - Nutrition by ID
nutrition_info = []
for id in random_df['id']:
    nutrition_url = f"https://api.spoonacular.com/recipes/{id}/nutritionWidget.json"
    nutrition_params = {'apiKey': spoonacular_key}

    nutrition_response = requests.get(nutrition_url, nutrition_params).json()
    nutrition_info.append(nutrition_response)

nutrition_df = pd.DataFrame(nutrition_info)
nutrition_df.to_csv('Resources/02_raw_data/info_master_5.csv')

# %%
metadata.columns

# %%
nutrition_info[0]['carbs']

# %%
# Parse results
metadata = pd.read_csv('Resources/01_recipe_IDs/initial_recipes_5.csv')
metadata

# Metadata
num_ingredients = []
carbs = []
# for row in metadata['extendedIngredients']:
#     print(row)

# Calories
calories_amt = []
calories_unit = []
calories_pct = []

# Saturated Fat
satfat_amt = []
satfat_unit = []
satfat_pct = []

# Sugar
sugar_amt = []
sugar_unit = []
sugar_pct = []

# Sodium
sodium_amt = []
sodium_unit = []
sodium_pct = []

# Protein
protein_amt = []
protein_unit = []
protein_pct = []

for idx, row in enumerate(nutrition_info):
    try:
        # recipe_id.append(nutrition_info[idx]['id'])
        # recipe_name.append(nutrition_info[idx]['title'])
        # recipe_likes.append(nutrition_info[idx]['aggregateLikes'])
        # meal_type.append(nutrition_info[idx]['dishTypes'])
        # cuisines.append(nutrition_info[idx]['cuisines'])
        # num_ingredients.append(len(recipe_info[idx]['extendedIngredients']))
        # ww_points.append(recipe_info[idx]['weightWatcherSmartPoints'])

        num_ingredients.append(len(nutrition_info[idx]['ingredients']))
        carbs.append(nutrition_info[idx]['carbs'])
        calories_amt.append(nutrition_info[idx]['nutrients'][0]['amount'])
        calories_unit.append(nutrition_info[idx]['nutrients'][0]['unit'])
        calories_pct.append(nutrition_info[idx]['nutrients'][0]['percentOfDailyNeeds'])
        
        satfat_amt.append(nutrition_info[idx]['nutrients'][2]['amount'])
        satfat_unit.append(nutrition_info[idx]['nutrients'][2]['unit'])
        satfat_pct.append(nutrition_info[idx]['nutrients'][2]['percentOfDailyNeeds'])
        
        sugar_amt.append(nutrition_info[idx]['nutrients'][5]['amount'])
        sugar_unit.append(nutrition_info[idx]['nutrients'][5]['unit'])
        sugar_pct.append(nutrition_info[idx]['nutrients'][5]['percentOfDailyNeeds'])
        
        sodium_amt.append(nutrition_info[idx]['nutrients'][7]['amount'])
        sodium_unit.append(nutrition_info[idx]['nutrients'][7]['unit'])
        sodium_pct.append(nutrition_info[idx]['nutrients'][7]['percentOfDailyNeeds'])
        
        protein_amt.append(nutrition_info[idx]['nutrients'][8]['amount'])
        protein_unit.append(nutrition_info[idx]['nutrients'][8]['unit'])
        protein_pct.append(nutrition_info[idx]['nutrients'][8]['percentOfDailyNeeds'])
    
    except:
        print(idx)

spoonacular_df = pd.DataFrame({
    'ID': metadata['id'],
    'Name': metadata['title'],
    'Likes': metadata['aggregateLikes'],
    'Meal Type': metadata['dishTypes'],
    'Cuisines': metadata['cuisines'],
    'N_ingredients': num_ingredients,
    'WW Smart Points': metadata['weightWatcherSmartPoints'],
    'Calories (Amount)': calories_amt,
    'Calories (Unit)': calories_unit,
    'Calories (% of Daily Needs)': calories_pct,
    'Saturated Fat (Amount)': satfat_amt,
    'Saturated Fat (Unit)': satfat_unit,
    'Saturated Fat (% of Daily Needs)': satfat_pct,
    'Sugar (Amount)': sugar_amt,
    'Sugar (Unit)': sugar_unit,
    'Sugar (% of Daily Needs)': sugar_pct,
    'Sodium (Amount)': sodium_amt,
    'Sodium (Unit)': sodium_unit,
    'Sodium (% of Daily Needs)': sodium_pct,
    'Protein (Amount)': protein_amt,
    'Protein (Unit)': protein_unit,
    'Protein (% of Daily Needs)': protein_pct,
    'Carbohydrates': carbs})

spoonacular_df.to_csv(f"Resources/03_simplified_data/initial_nutrition_5.csv", index=False)

# %% [markdown]
# # Data Collection
# - API request cost comparison:
#     1. `Random Recipes` + `Recipe Information` = 2.1 points per request
#     2. `Random Recipes` + `Nutrition` = 2 points per request

# %%
# API REQUEST - Random Recipe
random_url = "https://api.spoonacular.com/recipes/random?"

# Set request parameters
random_params = {
    'apiKey': spoonacular_key,
    'number': 100}

# Request a list of random recipe IDs.
random_response = requests.get(random_url, random_params).json()

# Output response to a csv
random_df = pd.DataFrame(random_response['recipes'])
random_df.to_csv(f'Resources/01_recipe_IDs/initial_recipes_{recipe_folder()}.csv', index=False)

# %%
# API REQUEST - Nutrition by ID
nutrition_info = []
for id in random_df['id']:
    nutrition_url = f"https://api.spoonacular.com/recipes/{id}/nutritionWidget.json"
    nutrition_params = {'apiKey': spoonacular_key}

    nutrition_response = requests.get(nutrition_url, nutrition_params).json()
    nutrition_info.append(nutrition_response)

nutrition_df = pd.DataFrame(nutrition_info)
nutrition_df.to_csv(f'Resources/02_raw_data/info_master_{raw_folder()}.csv')

# %%
# Parse results
metadata = pd.read_csv(f'Resources/01_recipe_IDs/initial_recipes_{recipe_folder()-1}.csv')
metadata

# Metadata
num_ingredients = []
carbs = []
# for row in metadata['extendedIngredients']:
#     print(row)

# Calories
calories_amt = []
calories_unit = []
calories_pct = []

# Saturated Fat
satfat_amt = []
satfat_unit = []
satfat_pct = []

# Sugar
sugar_amt = []
sugar_unit = []
sugar_pct = []

# Sodium
sodium_amt = []
sodium_unit = []
sodium_pct = []

# Protein
protein_amt = []
protein_unit = []
protein_pct = []

for idx, row in enumerate(nutrition_info):
    try:
        # recipe_id.append(nutrition_info[idx]['id'])
        # recipe_name.append(nutrition_info[idx]['title'])
        # recipe_likes.append(nutrition_info[idx]['aggregateLikes'])
        # meal_type.append(nutrition_info[idx]['dishTypes'])
        # cuisines.append(nutrition_info[idx]['cuisines'])
        # num_ingredients.append(len(recipe_info[idx]['extendedIngredients']))
        # ww_points.append(recipe_info[idx]['weightWatcherSmartPoints'])

        num_ingredients.append(len(nutrition_info[idx]['ingredients']))
        carbs.append(nutrition_info[idx]['carbs'])
        calories_amt.append(nutrition_info[idx]['nutrients'][0]['amount'])
        calories_unit.append(nutrition_info[idx]['nutrients'][0]['unit'])
        calories_pct.append(nutrition_info[idx]['nutrients'][0]['percentOfDailyNeeds'])
        
        satfat_amt.append(nutrition_info[idx]['nutrients'][2]['amount'])
        satfat_unit.append(nutrition_info[idx]['nutrients'][2]['unit'])
        satfat_pct.append(nutrition_info[idx]['nutrients'][2]['percentOfDailyNeeds'])
        
        sugar_amt.append(nutrition_info[idx]['nutrients'][5]['amount'])
        sugar_unit.append(nutrition_info[idx]['nutrients'][5]['unit'])
        sugar_pct.append(nutrition_info[idx]['nutrients'][5]['percentOfDailyNeeds'])
        
        sodium_amt.append(nutrition_info[idx]['nutrients'][7]['amount'])
        sodium_unit.append(nutrition_info[idx]['nutrients'][7]['unit'])
        sodium_pct.append(nutrition_info[idx]['nutrients'][7]['percentOfDailyNeeds'])
        
        protein_amt.append(nutrition_info[idx]['nutrients'][8]['amount'])
        protein_unit.append(nutrition_info[idx]['nutrients'][8]['unit'])
        protein_pct.append(nutrition_info[idx]['nutrients'][8]['percentOfDailyNeeds'])
    
    except:
        print(idx)
        pass

spoonacular_df = pd.DataFrame({
    'ID': metadata['id'],
    'Name': metadata['title'],
    'Likes': metadata['aggregateLikes'],
    'Meal Type': metadata['dishTypes'],
    'Cuisines': metadata['cuisines'],
    'N_ingredients': num_ingredients,
    'WW Smart Points': metadata['weightWatcherSmartPoints'],
    'Calories (Amount)': calories_amt,
    'Calories (Unit)': calories_unit,
    'Calories (% of Daily Needs)': calories_pct,
    'Saturated Fat (Amount)': satfat_amt,
    'Saturated Fat (Unit)': satfat_unit,
    'Saturated Fat (% of Daily Needs)': satfat_pct,
    'Sugar (Amount)': sugar_amt,
    'Sugar (Unit)': sugar_unit,
    'Sugar (% of Daily Needs)': sugar_pct,
    'Sodium (Amount)': sodium_amt,
    'Sodium (Unit)': sodium_unit,
    'Sodium (% of Daily Needs)': sodium_pct,
    'Protein (Amount)': protein_amt,
    'Protein (Unit)': protein_unit,
    'Protein (% of Daily Needs)': protein_pct,
    'Carbohydrates': carbs})

spoonacular_df.to_csv(f"Resources/03_simplified_data/initial_nutrition_{simple_folder()}.csv", index=False)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Add missing values from the raw data

# %%
simplified_data = pd.read_csv(f'Resources/03_simplified_data/initial_nutrition_{check_index()}.csv')
simplified_data.columns
simplified_data.shape
# Out:
# Select file type (recipe, raw, simple, complex):  simple
# Select file number (0-10):  3
# (33, 22)

# %%
simplified_data.head()
# Out:
#        ID                                 Name  Likes  \
# 0  645384           Greek Yogurt Chicken Salad      4
# 1  636271               Brooklyn Blackout Cake      6
# 2  639137  Chocolate Pavlova with Winter Fruit     13
# 3  634229                       Bananas Foster      4
# 4  660283       SLOW COOKER CHICKEN GUMBO SOUP      2
#
#                                            Meal Type  \
# 0    ['lunch', 'main course', 'main dish', 'dinner']
# 1                                        ['dessert']
# 2                                        ['dessert']
# 3                                        ['dessert']
# 4  ['antipasti', 'soup', 'starter', 'snack', 'app...
#
#                                  Cuisines  N_ingredients  WW Smart Points  \
# 0  ['Mediterranean', 'European', 'Greek']              7              6.0
# 1                                      []             14             12.0
# 2                                      []             12             13.0
# 3                     ['Creole', 'Cajun']              7             14.0
# 4                     ['Creole', 'Cajun']             14              5.0
#
#    Calories (Amount) Calories (Unit)  Calories (% of Daily Needs)  ...  \
# 0             334.09            kcal                        16.70  ...
# 1             328.77            kcal                        16.44  ...
# 2             283.94            kcal                        14.20  ...
# 3             507.90            kcal                        25.40  ...
# 4             351.07            kcal                        17.55  ...
#
#    Saturated Fat (% of Daily Needs) Sugar (Amount)  Sugar (Unit)  \
# 0                             15.31           9.21             g
# 1                             47.34           8.25             g
# 2                             64.70          29.74             g
# 3                             45.82          66.50             g
# 4                              8.55           6.26             g
#
#    Sugar (% of Daily Needs) Sodium (Amount)  Sodium (Unit)  \
# 0                     10.24          318.44             mg
# 1                      9.16          305.10             mg
# 2                     33.05           32.36             mg
# 3                     73.89          105.02             mg
# 4                      6.96          764.99             mg
#
#    Sodium (% of Daily Needs) Protein (Amount)  Protein (Unit)  \
# 0                      13.85            41.31               g
# 1                      13.27            29.67              mg
# 2                       1.41             5.70              mg
# 3                       4.57            13.06               g
# 4                      33.26            12.98               g
#
#    Protein (% of Daily Needs)
# 0                       82.62
# 1                        9.89
# 2                        1.90
# 3                       72.57
# 4                       25.96
#
# [5 rows x 22 columns]

# %%
raw_data = pd.read_csv(f'Resources/02_raw_data/info_master_{check_index()}.csv')
raw_data['weightWatcherSmartPoints']
# Out:
# Select file type (recipe, raw, simple, complex):  raw
# Select file number (0-11):  3
# 0      6.0
# 1     12.0
# 2     13.0
# 3     14.0
# 4      5.0
#       ...
# 95     NaN
# 96     NaN
# 97     NaN
# 98     NaN
# 99     NaN
# Name: weightWatcherSmartPoints, Length: 100, dtype: float64

# %%
simplified_data.insert(6, column='WW Smart Points', value=raw_data['weightWatcherSmartPoints'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 simplified_data.insert(6, column='WW Smart Points', value=raw_data['weightWatcherSmartPoints'])
#
# File ~\AppData\Local\anaconda3\envs\PythonData\Lib\site-packages\pandas\core\frame.py:4772, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4766     raise ValueError(
#    4767         "Cannot specify 'allow_duplicates=True' when "
#    4768         "'self.flags.allows_duplicate_labels' is False."
#    4769     )
#    4770 if not allow_duplicates and column in self.columns:
#    4771     # Should this be a different kind of error??
# -> 4772     raise ValueError(f"cannot insert {column}, already exists")
#    4773 if not isinstance(loc, int):
#    4774     raise TypeError("loc must be int")
#
# ValueError: cannot insert WW Smart Points, already exists

# %%
simplified_data.head()
# Out:
#        ID                                 Name  Likes  \
# 0  645384           Greek Yogurt Chicken Salad      4
# 1  636271               Brooklyn Blackout Cake      6
# 2  639137  Chocolate Pavlova with Winter Fruit     13
# 3  634229                       Bananas Foster      4
# 4  660283       SLOW COOKER CHICKEN GUMBO SOUP      2
#
#                                            Meal Type  \
# 0    ['lunch', 'main course', 'main dish', 'dinner']
# 1                                        ['dessert']
# 2                                        ['dessert']
# 3                                        ['dessert']
# 4  ['antipasti', 'soup', 'starter', 'snack', 'app...
#
#                                  Cuisines  N_ingredients  WW Smart Points  \
# 0  ['Mediterranean', 'European', 'Greek']              7              6.0
# 1                                      []             14             12.0
# 2                                      []             12             13.0
# 3                     ['Creole', 'Cajun']              7             14.0
# 4                     ['Creole', 'Cajun']             14              5.0
#
#    Calories (Amount) Calories (Unit)  Calories (% of Daily Needs)  ...  \
# 0             334.09            kcal                        16.70  ...
# 1             328.77            kcal                        16.44  ...
# 2             283.94            kcal                        14.20  ...
# 3             507.90            kcal                        25.40  ...
# 4             351.07            kcal                        17.55  ...
#
#    Saturated Fat (% of Daily Needs) Sugar (Amount)  Sugar (Unit)  \
# 0                             15.31           9.21             g
# 1                             47.34           8.25             g
# 2                             64.70          29.74             g
# 3                             45.82          66.50             g
# 4                              8.55           6.26             g
#
#    Sugar (% of Daily Needs) Sodium (Amount)  Sodium (Unit)  \
# 0                     10.24          318.44             mg
# 1                      9.16          305.10             mg
# 2                     33.05           32.36             mg
# 3                     73.89          105.02             mg
# 4                      6.96          764.99             mg
#
#    Sodium (% of Daily Needs) Protein (Amount)  Protein (Unit)  \
# 0                      13.85            41.31               g
# 1                      13.27            29.67              mg
# 2                       1.41             5.70              mg
# 3                       4.57            13.06               g
# 4                      33.26            12.98               g
#
#    Protein (% of Daily Needs)
# 0                       82.62
# 1                        9.89
# 2                        1.90
# 3                       72.57
# 4                       25.96
#
# [5 rows x 22 columns]

# %%
simplified_data.to_csv('Resources/03_simplified_data/initial_nutrition_3.csv', index=False)

# %% [markdown]
# ## Test plot on one dataset

# %%
x_values = simplified_data["WW Smart Points"]
y_values = simplified_data["N_ingredients"]
scatter_plot = simplified_data.plot(kind="scatter", x="WW Smart Points", y="N_ingredients")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept

r_value = pearsonr(x_values, y_values)
print(f"R-value: {round(r_value[0]**2, 4)}")
plt.plot(x_values, regression_values, color='red')
plt.show()
# Out:
# R-value: 0.05

# %% [markdown]
# ## Get RECIPE IDs without data

# %%
cuisine_match
cuisine_string = str(cuisine_match)
cuisine_string = cuisine_string.strip("[]")
cuisine_string = cuisine_string.replace(" ","")
cuisine_string
# Out:
# "'african','american','asian','cajun','caribbean','chinese','european','french','german','greek','indian','irish','italian','japanese','korean','mexican','spanish','thai','vietnamese'"

# %%
# API REQUEST - Complex Search.
recipe_url = "https://api.spoonacular.com/recipes/complexSearch"

# Set request parameters
recipe_params = {
    'apiKey': spoonacular_key,
    'number': 100,
    # 'excludeCuisine': cuisine_mismatch,
    # 'cuisine': "african,american,asian,cajun,caribbean,chinese,european,french,german,greek,indian,,
    'cuisine': cuisine_string,
    'type': "lunch",
    'addRecipeNutrition': True}

# Request a list of recipes.
recipe_response = requests.get(recipe_url, recipe_params).json()
recipe_response

# Output response to a csv
recipes_df = pd.DataFrame(recipe_response['results'])
recipes_df.to_csv(f'Resources/04_complex_test/recipe_data_{complex_folder()}.csv', index=False)

# %%
recipe_response['results'][0]['nutrition']['ingredients']
# Out:
# [{'id': 1009040,
#   'name': 'banana',
#   'amount': 0.25,
#   'unit': 'cup',
#   'nutrients': [{'name': 'Calories',
#     'amount': 50.06,
#     'unit': 'kcal',
#     'percentOfDailyNeeds': 22.85},
#    {'name': 'Copper',
#     'amount': 0.04,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 20.21},
#    {'name': 'Zinc',
#     'amount': 0.08,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 20.16},
#    {'name': 'Vitamin K',
#     'amount': 0.28,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 1.99},
#    {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g', 'percentOfDailyNeeds': 0.0},
#    {'name': 'Iron',
#     'amount': 0.15,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 14.35},
#    {'name': 'Vitamin B2',
#     'amount': 0.04,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 60.64},
#    {'name': 'Sodium',
#     'amount': 0.56,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 17.43},
#    {'name': 'Net Carbohydrates',
#     'amount': 11.36,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.92},
#    {'name': 'Carbohydrates',
#     'amount': 12.82,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.35},
#    {'name': 'Protein',
#     'amount': 0.61,
#     'unit': 'g',
#     'percentOfDailyNeeds': 41.25},
#    {'name': 'Vitamin A',
#     'amount': 36.0,
#     'unit': 'IU',
#     'percentOfDailyNeeds': 21.39},
#    {'name': 'Lycopene',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Saturated Fat',
#     'amount': 0.06,
#     'unit': 'g',
#     'percentOfDailyNeeds': 16.88},
#    {'name': 'Vitamin B6',
#     'amount': 0.21,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 45.62},
#    {'name': 'Magnesium',
#     'amount': 15.19,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 18.17},
#    {'name': 'Phosphorus',
#     'amount': 12.38,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 37.65},
#    {'name': 'Vitamin B1',
#     'amount': 0.02,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 21.47},
#    {'name': 'Fiber',
#     'amount': 1.46,
#     'unit': 'g',
#     'percentOfDailyNeeds': 18.11},
#    {'name': 'Mono Unsaturated Fat',
#     'amount': 0.02,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Folic Acid',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Poly Unsaturated Fat',
#     'amount': 0.04,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Selenium',
#     'amount': 0.56,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 24.86},
#    {'name': 'Vitamin B3',
#     'amount': 0.37,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 47.1},
#    {'name': 'Manganese',
#     'amount': 0.15,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 21.94},
#    {'name': 'Fat', 'amount': 0.19, 'unit': 'g', 'percentOfDailyNeeds': 15.29},
#    {'name': 'Calcium',
#     'amount': 2.81,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 74.87},
#    {'name': 'Vitamin E',
#     'amount': 0.06,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 41.72},
#    {'name': 'Choline',
#     'amount': 5.51,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Vitamin D',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 18.88},
#    {'name': 'Vitamin B5',
#     'amount': 0.19,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 15.31},
#    {'name': 'Caffeine',
#     'amount': 0.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Cholesterol',
#     'amount': 0.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 3.78},
#    {'name': 'Vitamin B12',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 62.53},
#    {'name': 'Fluoride',
#     'amount': 1.24,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Potassium',
#     'amount': 201.38,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 33.62},
#    {'name': 'Folate',
#     'amount': 11.25,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 34.56},
#    {'name': 'Sugar',
#     'amount': 6.86,
#     'unit': 'g',
#     'percentOfDailyNeeds': 58.09},
#    {'name': 'Vitamin C',
#     'amount': 4.89,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 80.05}]},
#  {'id': 10018617,
#   'name': 'graham cracker crumbs',
#   'amount': 2.0,
#   'unit': 'tbsp',
#   'nutrients': [{'name': 'Calories',
#     'amount': 84.8,
#     'unit': 'kcal',
#     'percentOfDailyNeeds': 22.85},
#    {'name': 'Copper',
#     'amount': 0.01,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 20.21},
#    {'name': 'Zinc',
#     'amount': 0.39,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 20.16},
#    {'name': 'Iron',
#     'amount': 0.83,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 14.35},
#    {'name': 'Vitamin B2',
#     'amount': 0.05,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 60.64},
#    {'name': 'Sodium',
#     'amount': 131.8,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 17.43},
#    {'name': 'Carbohydrates',
#     'amount': 15.24,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.35},
#    {'name': 'Protein',
#     'amount': 1.4,
#     'unit': 'g',
#     'percentOfDailyNeeds': 41.25},
#    {'name': 'Vitamin A',
#     'amount': 0.0,
#     'unit': 'IU',
#     'percentOfDailyNeeds': 21.39},
#    {'name': 'Net Carbohydrates',
#     'amount': 14.56,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.92},
#    {'name': 'Magnesium',
#     'amount': 11.8,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 18.17},
#    {'name': 'Saturated Fat',
#     'amount': 0.31,
#     'unit': 'g',
#     'percentOfDailyNeeds': 16.88},
#    {'name': 'Vitamin B6',
#     'amount': 0.02,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 45.62},
#    {'name': 'Phosphorus',
#     'amount': 40.4,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 37.65},
#    {'name': 'Vitamin B1',
#     'amount': 0.05,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 21.47},
#    {'name': 'Fiber',
#     'amount': 0.68,
#     'unit': 'g',
#     'percentOfDailyNeeds': 18.11},
#    {'name': 'Mono Unsaturated Fat',
#     'amount': 0.72,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Poly Unsaturated Fat',
#     'amount': 0.09,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Vitamin B3',
#     'amount': 0.76,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 47.1},
#    {'name': 'Fat', 'amount': 2.0, 'unit': 'g', 'percentOfDailyNeeds': 15.29},
#    {'name': 'Calcium',
#     'amount': 15.8,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 74.87},
#    {'name': 'Potassium',
#     'amount': 35.4,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 33.62},
#    {'name': 'Cholesterol',
#     'amount': 0.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 3.78},
#    {'name': 'Sugar', 'amount': 4.6, 'unit': 'g', 'percentOfDailyNeeds': 58.09},
#    {'name': 'Folate',
#     'amount': 9.2,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 34.56},
#    {'name': 'Vitamin C',
#     'amount': 0.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 80.05}]},
#  {'id': 16223,
#   'name': 'soy milk',
#   'amount': 1.0,
#   'unit': 'cup',
#   'nutrients': [{'name': 'Calories',
#     'amount': 106.2,
#     'unit': 'kcal',
#     'percentOfDailyNeeds': 22.85},
#    {'name': 'Trans Fat',
#     'amount': 0.0,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Copper',
#     'amount': 0.29,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 20.21},
#    {'name': 'Zinc',
#     'amount': 0.57,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 20.16},
#    {'name': 'Iron',
#     'amount': 1.16,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 14.35},
#    {'name': 'Vitamin B2',
#     'amount': 0.47,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 60.64},
#    {'name': 'Sodium',
#     'amount': 118.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 17.43},
#    {'name': 'Carbohydrates',
#     'amount': 8.14,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.35},
#    {'name': 'Protein',
#     'amount': 6.94,
#     'unit': 'g',
#     'percentOfDailyNeeds': 41.25},
#    {'name': 'Vitamin A',
#     'amount': 927.48,
#     'unit': 'IU',
#     'percentOfDailyNeeds': 21.39},
#    {'name': 'Saturated Fat',
#     'amount': 0.49,
#     'unit': 'g',
#     'percentOfDailyNeeds': 16.88},
#    {'name': 'Vitamin B6',
#     'amount': 0.55,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 45.62},
#    {'name': 'Net Carbohydrates',
#     'amount': 7.2,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.92},
#    {'name': 'Vitamin B1',
#     'amount': 0.15,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 21.47},
#    {'name': 'Fiber',
#     'amount': 0.94,
#     'unit': 'g',
#     'percentOfDailyNeeds': 18.11},
#    {'name': 'Mono Unsaturated Fat',
#     'amount': 0.97,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Poly Unsaturated Fat',
#     'amount': 2.81,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Selenium',
#     'amount': 5.43,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 24.86},
#    {'name': 'Vitamin B3',
#     'amount': 7.77,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 47.1},
#    {'name': 'Fat', 'amount': 4.7, 'unit': 'g', 'percentOfDailyNeeds': 15.29},
#    {'name': 'Calcium',
#     'amount': 330.4,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 74.87},
#    {'name': 'Vitamin E',
#     'amount': 5.95,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 41.72},
#    {'name': 'Vitamin D',
#     'amount': 2.83,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 18.88},
#    {'name': 'Sugar',
#     'amount': 5.97,
#     'unit': 'g',
#     'percentOfDailyNeeds': 58.09},
#    {'name': 'Potassium',
#     'amount': 332.76,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 33.62},
#    {'name': 'Cholesterol',
#     'amount': 0.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 3.78},
#    {'name': 'Folate',
#     'amount': 75.52,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 34.56},
#    {'name': 'Vitamin B12',
#     'amount': 2.55,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 62.53},
#    {'name': 'Vitamin C',
#     'amount': 16.99,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 80.05}]},
#  {'id': 9316,
#   'name': 'strawberries',
#   'amount': 0.5,
#   'unit': 'cup',
#   'nutrients': [{'name': 'Calories',
#     'amount': 23.04,
#     'unit': 'kcal',
#     'percentOfDailyNeeds': 22.85},
#    {'name': 'Copper',
#     'amount': 0.03,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 20.21},
#    {'name': 'Zinc', 'amount': 0.1, 'unit': 'mg', 'percentOfDailyNeeds': 20.16},
#    {'name': 'Vitamin K',
#     'amount': 1.58,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 1.99},
#    {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g', 'percentOfDailyNeeds': 0.0},
#    {'name': 'Iron', 'amount': 0.3, 'unit': 'mg', 'percentOfDailyNeeds': 14.35},
#    {'name': 'Vitamin B2',
#     'amount': 0.02,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 60.64},
#    {'name': 'Sodium',
#     'amount': 0.72,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 17.43},
#    {'name': 'Net Carbohydrates',
#     'amount': 4.09,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.92},
#    {'name': 'Carbohydrates',
#     'amount': 5.53,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.35},
#    {'name': 'Protein',
#     'amount': 0.48,
#     'unit': 'g',
#     'percentOfDailyNeeds': 41.25},
#    {'name': 'Vitamin A',
#     'amount': 8.64,
#     'unit': 'IU',
#     'percentOfDailyNeeds': 21.39},
#    {'name': 'Lycopene',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Saturated Fat',
#     'amount': 0.01,
#     'unit': 'g',
#     'percentOfDailyNeeds': 16.88},
#    {'name': 'Vitamin B6',
#     'amount': 0.03,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 45.62},
#    {'name': 'Magnesium',
#     'amount': 9.36,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 18.17},
#    {'name': 'Phosphorus',
#     'amount': 17.28,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 37.65},
#    {'name': 'Vitamin B1',
#     'amount': 0.02,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 21.47},
#    {'name': 'Fiber',
#     'amount': 1.44,
#     'unit': 'g',
#     'percentOfDailyNeeds': 18.11},
#    {'name': 'Mono Unsaturated Fat',
#     'amount': 0.03,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Folic Acid',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Poly Unsaturated Fat',
#     'amount': 0.11,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Selenium',
#     'amount': 0.29,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 24.86},
#    {'name': 'Vitamin B3',
#     'amount': 0.28,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 47.1},
#    {'name': 'Manganese',
#     'amount': 0.28,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 21.94},
#    {'name': 'Fat', 'amount': 0.22, 'unit': 'g', 'percentOfDailyNeeds': 15.29},
#    {'name': 'Calcium',
#     'amount': 11.52,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 74.87},
#    {'name': 'Vitamin E',
#     'amount': 0.21,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 41.72},
#    {'name': 'Choline',
#     'amount': 4.1,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Vitamin D',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 18.88},
#    {'name': 'Vitamin B5',
#     'amount': 0.09,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 15.31},
#    {'name': 'Caffeine',
#     'amount': 0.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Cholesterol',
#     'amount': 0.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 3.78},
#    {'name': 'Vitamin B12',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 62.53},
#    {'name': 'Fluoride',
#     'amount': 3.17,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Potassium',
#     'amount': 110.16,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 33.62},
#    {'name': 'Folate',
#     'amount': 17.28,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 34.56},
#    {'name': 'Sugar',
#     'amount': 3.52,
#     'unit': 'g',
#     'percentOfDailyNeeds': 58.09},
#    {'name': 'Vitamin C',
#     'amount': 42.34,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 80.05}]},
#  {'id': 1119,
#   'name': 'vanilla yogurt',
#   'amount': 1.0,
#   'unit': 'container',
#   'nutrients': [{'name': 'Calories',
#     'amount': 192.95,
#     'unit': 'kcal',
#     'percentOfDailyNeeds': 22.85},
#    {'name': 'Copper',
#     'amount': 0.03,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 20.21},
#    {'name': 'Zinc',
#     'amount': 1.88,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 20.16},
#    {'name': 'Vitamin K',
#     'amount': 0.23,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 1.99},
#    {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g', 'percentOfDailyNeeds': 0.0},
#    {'name': 'Iron',
#     'amount': 0.16,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 14.35},
#    {'name': 'Vitamin B2',
#     'amount': 0.46,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 60.64},
#    {'name': 'Sodium',
#     'amount': 149.82,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 17.43},
#    {'name': 'Net Carbohydrates',
#     'amount': 31.33,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.92},
#    {'name': 'Carbohydrates',
#     'amount': 31.33,
#     'unit': 'g',
#     'percentOfDailyNeeds': 24.35},
#    {'name': 'Protein',
#     'amount': 11.19,
#     'unit': 'g',
#     'percentOfDailyNeeds': 41.25},
#    {'name': 'Vitamin A',
#     'amount': 97.61,
#     'unit': 'IU',
#     'percentOfDailyNeeds': 21.39},
#    {'name': 'Lycopene',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Saturated Fat',
#     'amount': 1.83,
#     'unit': 'g',
#     'percentOfDailyNeeds': 16.88},
#    {'name': 'Vitamin B6',
#     'amount': 0.1,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 45.62},
#    {'name': 'Magnesium',
#     'amount': 36.32,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 18.17},
#    {'name': 'Phosphorus',
#     'amount': 306.45,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 37.65},
#    {'name': 'Vitamin B1',
#     'amount': 0.1,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 21.47},
#    {'name': 'Fiber', 'amount': 0.0, 'unit': 'g', 'percentOfDailyNeeds': 18.11},
#    {'name': 'Mono Unsaturated Fat',
#     'amount': 0.78,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Folic Acid',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Poly Unsaturated Fat',
#     'amount': 0.08,
#     'unit': 'g',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Selenium',
#     'amount': 11.12,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 24.86},
#    {'name': 'Vitamin B3',
#     'amount': 0.24,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 47.1},
#    {'name': 'Manganese',
#     'amount': 0.01,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 21.94},
#    {'name': 'Fat', 'amount': 2.84, 'unit': 'g', 'percentOfDailyNeeds': 15.29},
#    {'name': 'Calcium',
#     'amount': 388.17,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 74.87},
#    {'name': 'Vitamin E',
#     'amount': 0.05,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 41.72},
#    {'name': 'Choline',
#     'amount': 34.5,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Vitamin D',
#     'amount': 0.0,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 18.88},
#    {'name': 'Vitamin B5',
#     'amount': 1.25,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 15.31},
#    {'name': 'Caffeine',
#     'amount': 0.0,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Cholesterol',
#     'amount': 11.35,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 3.78},
#    {'name': 'Vitamin B12',
#     'amount': 1.2,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 62.53},
#    {'name': 'Fluoride',
#     'amount': 27.24,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 0.0},
#    {'name': 'Potassium',
#     'amount': 497.13,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 33.62},
#    {'name': 'Folate',
#     'amount': 24.97,
#     'unit': 'µg',
#     'percentOfDailyNeeds': 34.56},
#    {'name': 'Sugar',
#     'amount': 31.33,
#     'unit': 'g',
#     'percentOfDailyNeeds': 58.09},
#    {'name': 'Vitamin C',
#     'amount': 1.82,
#     'unit': 'mg',
#     'percentOfDailyNeeds': 80.05}]}]

# %%
# Metadata
recipe_id = []
recipe_name = []
recipe_likes = []
meal_type = []
cuisines = []
num_ingredients = []
ww_points = []
mins_cook = []
mins_prep = []

# Calories
calories_amt = []
calories_unit = []
calories_pct = []

# Saturated Fat
satfat_amt = []
satfat_unit = []
satfat_pct = []

# Sugar
sugar_amt = []
sugar_unit = []
sugar_pct = []

# Sodium
sodium_amt = []
sodium_unit = []
sodium_pct = []

# Protein
protein_amt = []
protein_unit = []
protein_pct = []

# Carbohydrates
carbs_amt = []
carbs_unit = []
carbs_pct = []

recipe_info = recipe_response['results']
for idx, row in enumerate(recipe_info):
    recipe_id.append(recipe_info[idx]['id'])
    recipe_name.append(recipe_info[idx]['title'])
    recipe_likes.append(recipe_info[idx]['aggregateLikes'])
    meal_type.append(recipe_info[idx]['dishTypes'])
    cuisines.append(recipe_info[idx]['cuisines'])
    num_ingredients.append(len(recipe_info[idx]['nutrition']['ingredients']))
    ww_points.append(recipe_info[idx]['weightWatcherSmartPoints'])
    mins_cook.append(recipe_info[idx]['cookingMinutes'])
    mins_prep.append(recipe_info[idx]['preparationMinutes'])
    
    calories_amt.append(recipe_info[idx]['nutrition']['nutrients'][0]['amount'])
    calories_unit.append(recipe_info[idx]['nutrition']['nutrients'][0]['unit'])
    calories_pct.append(recipe_info[idx]['nutrition']['nutrients'][0]['percentOfDailyNeeds'])
    
    satfat_amt.append(recipe_info[idx]['nutrition']['nutrients'][2]['amount'])
    satfat_unit.append(recipe_info[idx]['nutrition']['nutrients'][2]['unit'])
    satfat_pct.append(recipe_info[idx]['nutrition']['nutrients'][2]['percentOfDailyNeeds'])
    
    sugar_amt.append(recipe_info[idx]['nutrition']['nutrients'][5]['amount'])
    sugar_unit.append(recipe_info[idx]['nutrition']['nutrients'][5]['unit'])
    sugar_pct.append(recipe_info[idx]['nutrition']['nutrients'][5]['percentOfDailyNeeds'])
    
    sodium_amt.append(recipe_info[idx]['nutrition']['nutrients'][7]['amount'])
    sodium_unit.append(recipe_info[idx]['nutrition']['nutrients'][7]['unit'])
    sodium_pct.append(recipe_info[idx]['nutrition']['nutrients'][7]['percentOfDailyNeeds'])
    
    protein_amt.append(recipe_info[idx]['nutrition']['nutrients'][8]['amount'])
    protein_unit.append(recipe_info[idx]['nutrition']['nutrients'][8]['unit'])
    protein_pct.append(recipe_info[idx]['nutrition']['nutrients'][8]['percentOfDailyNeeds'])

    carbs_amt.append(recipe_info[idx]['nutrition']['nutrients'][8]['amount'])
    carbs_unit.append(recipe_info[idx]['nutrition']['nutrients'][8]['unit'])
    carbs_pct.append(recipe_info[idx]['nutrition']['nutrients'][8]['percentOfDailyNeeds'])

spoonacular_df = pd.DataFrame({
    'ID': recipe_id,
    'Name': recipe_name,
    'Likes': recipe_likes,
    'Meal Type': meal_type,
    'Cuisines': cuisines,
    'N_ingredients': num_ingredients,
    'WW Smart Points': ww_points,
    'Cooking Minutes': mins_cook,
    'Prep Minutes': mins_prep,
    'Calories (Amount)': calories_amt,
    'Calories (Unit)': calories_unit,
    'Calories (% of Daily Needs)': calories_pct,
    'Saturated Fat (Amount)': satfat_amt,
    'Saturated Fat (Unit)': satfat_unit,
    'Saturated Fat (% of Daily Needs)': satfat_pct,
    'Sugar (Amount)': sugar_amt,
    'Sugar (Unit)': sugar_unit,
    'Sugar (% of Daily Needs)': sugar_pct,
    'Sodium (Amount)': sodium_amt,
    'Sodium (Unit)': sodium_unit,
    'Sodium (% of Daily Needs)': sodium_pct,
    'Protein (Amount)': protein_amt,
    'Protein (Unit)': protein_unit,
    'Protein (% of Daily Needs)': protein_pct,
    'Carbs (Amount)': carbs_amt,
    'Carbs (Unit)': carbs_unit,
    'Carbs (% of Daily Needs)': carbs_pct})

spoonacular_df.to_csv(f"Resources/04_complex_test/simplified_data_{complex_folder()-2}.csv", index=False)

# %% [markdown]
# ## Combine all the spreadsheets

# %%
#identifing the column name of each nutrition csv's
nutrition0_df = pd.read_csv("Resources/03_simplified_data/initial_nutrition_0.csv")
nutrition1_df = pd.read_csv("Resources/03_simplified_data/initial_nutrition_1.csv")
nutrition2_df = pd.read_csv("Resources/03_simplified_data/initial_nutrition_2.csv")
nutrition3_df = pd.read_csv("Resources/03_simplified_data/initial_nutrition_3.csv")
nutrition4_df = pd.read_csv("Resources/03_simplified_data/initial_nutrition_4.csv")
nutrition5_df = pd.read_csv("Resources/03_simplified_data/initial_nutrition_5.csv")
nutrition7_df = pd.read_csv("Resources/03_simplified_data/initial_nutrition_7.csv")
nutrition10_df = pd.read_csv("Resources/03_simplified_data/initial_nutrition_10.csv")
nutrition11_df = pd.read_csv("Resources/03_simplified_data/initial_nutrition_11.csv")
#nutrition1_df.count()

# %%
nutrition_all = pd.concat(
    [nutrition0_df, nutrition1_df, nutrition2_df, nutrition3_df, nutrition4_df, nutrition5_df,
     nutrition7_df, nutrition10_df, nutrition11_df], ignore_index=True)
nutrition_all = nutrition_all.drop(columns='Carbohydrates')
nutrition_all.head()
# Out:
#        ID                                               Name  Likes  \
# 0  782585  Cannellini Bean and Asparagus Salad with Mushr...    309
# 1  716426  Cauliflower, Brown Rice, and Vegetable Fried Rice   3689
# 2  715497                    Berry Banana Breakfast Smoothie    689
# 3  715415           Red Lentil Soup with Chicken and Turnips   1866
# 4  716406      Asparagus and Pea Soup: Real Convenience Food    207
#
#                                            Meal Type              Cuisines  \
# 0  ['side dish', 'lunch', 'main course', 'salad',...                    []
# 1  ['side dish', 'antipasti', 'starter', 'snack',...  ['Chinese', 'Asian']
# 2  ['morning meal', 'brunch', 'beverage', 'breakf...                    []
# 3  ['lunch', 'soup', 'main course', 'main dish', ...                    []
# 4  ['antipasti', 'soup', 'starter', 'snack', 'app...                    []
#
#    N_ingredients  WW Smart Points  Calories (Amount) Calories (Unit)  \
# 0             13             12.0             488.93            kcal
# 1             15              4.0             220.82            kcal
# 2              5             15.0             457.05            kcal
# 3             13             11.0             477.24            kcal
# 4              8              2.0             452.33            kcal
#
#    Calories (% of Daily Needs)  ...  Saturated Fat (% of Daily Needs)  \
# 0                        24.45  ...                              6.49
# 1                        11.04  ...                              6.99
# 2                        22.85  ...                             16.88
# 3                        23.86  ...                             19.37
# 4                        22.62  ...                              8.34
#
#   Sugar (Amount)  Sugar (Unit)  Sugar (% of Daily Needs) Sodium (Amount)  \
# 0           4.29             g                      4.76          421.70
# 1           5.29             g                      5.87          445.90
# 2          52.28             g                     58.09          400.90
# 3          10.55             g                     11.72         1335.78
# 4          27.99             g                     31.10           25.76
#
#    Sodium (Unit)  Sodium (% of Daily Needs) Protein (Amount)  Protein (Unit)  \
# 0             mg                      18.33            32.02               g
# 1             mg                      19.39             9.03               g
# 2             mg                      17.43            20.62               g
# 3             mg                      58.08            26.93               g
# 4             mg                       1.12            26.56               g
#
#    Protein (% of Daily Needs)
# 0                       64.03
# 1                       18.05
# 2                       41.25
# 3                       53.86
# 4                       53.12
#
# [5 rows x 22 columns]

# %%
# Check for duplicate IDs
nutrition_duplicates = nutrition_all.loc[nutrition_all.duplicated(['ID'])]
duplicates = len(nutrition_duplicates)
duplicates

nutrition_unique = nutrition_all.drop_duplicates(subset=['ID'])
nutrition_unique.head()
# Out:
#        ID                                               Name  Likes  \
# 0  782585  Cannellini Bean and Asparagus Salad with Mushr...    309
# 1  716426  Cauliflower, Brown Rice, and Vegetable Fried Rice   3689
# 2  715497                    Berry Banana Breakfast Smoothie    689
# 3  715415           Red Lentil Soup with Chicken and Turnips   1866
# 4  716406      Asparagus and Pea Soup: Real Convenience Food    207
#
#                                            Meal Type              Cuisines  \
# 0  ['side dish', 'lunch', 'main course', 'salad',...                    []
# 1  ['side dish', 'antipasti', 'starter', 'snack',...  ['Chinese', 'Asian']
# 2  ['morning meal', 'brunch', 'beverage', 'breakf...                    []
# 3  ['lunch', 'soup', 'main course', 'main dish', ...                    []
# 4  ['antipasti', 'soup', 'starter', 'snack', 'app...                    []
#
#    N_ingredients  WW Smart Points  Calories (Amount) Calories (Unit)  \
# 0             13             12.0             488.93            kcal
# 1             15              4.0             220.82            kcal
# 2              5             15.0             457.05            kcal
# 3             13             11.0             477.24            kcal
# 4              8              2.0             452.33            kcal
#
#    Calories (% of Daily Needs)  ...  Saturated Fat (% of Daily Needs)  \
# 0                        24.45  ...                              6.49
# 1                        11.04  ...                              6.99
# 2                        22.85  ...                             16.88
# 3                        23.86  ...                             19.37
# 4                        22.62  ...                              8.34
#
#   Sugar (Amount)  Sugar (Unit)  Sugar (% of Daily Needs) Sodium (Amount)  \
# 0           4.29             g                      4.76          421.70
# 1           5.29             g                      5.87          445.90
# 2          52.28             g                     58.09          400.90
# 3          10.55             g                     11.72         1335.78
# 4          27.99             g                     31.10           25.76
#
#    Sodium (Unit)  Sodium (% of Daily Needs) Protein (Amount)  Protein (Unit)  \
# 0             mg                      18.33            32.02               g
# 1             mg                      19.39             9.03               g
# 2             mg                      17.43            20.62               g
# 3             mg                      58.08            26.93               g
# 4             mg                       1.12            26.56               g
#
#    Protein (% of Daily Needs)
# 0                       64.03
# 1                       18.05
# 2                       41.25
# 3                       53.86
# 4                       53.12
#
# [5 rows x 22 columns]

# %%
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
       # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
x_axis = nutrition_unique['N_ingredients']
y_axis = nutrition_unique['Likes']
plt.xlabel("Number of Ingrediants")
plt.ylabel("Number of Likes")
plot_linear_regression(x_axis, y_axis,"title", (20, 10000))
# Out:
# The r-squared is: 0.009604629040114271

# %%
x_axis = nutrition_unique['Likes']
y_axis = nutrition_unique['WW Smart Points']
plt.xlabel("Number of Likes")
plt.ylabel("WW Smart Points")
plot_linear_regression(x_axis, y_axis,"title", (20000, 300))
# Out:
# The r-squared is: -0.010855630129144032

# %%
x_axis = nutrition_unique['N_ingredients']
y_axis = nutrition_unique['WW Smart Points']
plt.xlabel("Number of Ingrediants")
plt.ylabel("WW Smart Points")
plot_linear_regression(x_axis, y_axis,"title", (20, 400))
# Out:
# The r-squared is: 0.07303286179637895

# %% [markdown]
# ## Get meal types

# %%
nutrition_unique['Meal Type'][0]
# Out:
# "['side dish', 'lunch', 'main course', 'salad', 'main dish', 'dinner']"

# %%
# Get a list of meal types
unique_meals = []
for string in nutrition_unique['Meal Type']:
    meal_list = string.strip("[]").split(', ')
    for word_idx in range(len(meal_list)):
        meal = meal_list[word_idx].strip("'")
        if meal not in unique_meals:
            unique_meals.append(meal)

# Display the tags alphabetically
print(f"Number of unique meals: {len(unique_meals)}")
sorted(unique_meals)
# Out:
# Number of unique meals: 28
# ['',
#  '"hor d\'oeuvre"',
#  'antipasti',
#  'antipasto',
#  'appetizer',
#  'beverage',
#  'bread',
#  'breakfast',
#  'brunch',
#  'condiment',
#  'dessert',
#  'dinner',
#  'dip',
#  'drink',
#  'fingerfood',
#  'lunch',
#  'main course',
#  'main dish',
#  'marinade',
#  'morning meal',
#  'salad',
#  'sauce',
#  'seasoning',
#  'side dish',
#  'snack',
#  'soup',
#  'spread',
#  'starter']

# %%
# Count how many rows contain each meal type
meal_types = ["breakfast", "lunch", "dinner"]

break_count = 0
lunch_count = 0
dinner_count = 0
multiple = 0
total = 0

break_list = []
lunch_list = []
dinner_list = []
multiple_list = []

for idx, string in nutrition_unique.iterrows():
    # Strip and split the string to a list
    meal_list = string['Meal Type'].strip("[]").split(', ')
    # print(meal_list)
    # Get each tag from the list and categorise

    # Score tracks mutual exclusivity of the meal types
    score = 0
    for word_idx in range(len(meal_list)):
        # Check the tag
        meal = meal_list[word_idx].strip("'")
        # print(meal)     

        if (meal in meal_types):
            total += 1
            if (meal == "breakfast"):
                break_list.append(string['ID'])
                break_count += 1
                score += 1
            if (meal == "lunch"):
                lunch_list.append(string['ID'])
                lunch_count += 1
                score += 1
            if (meal == "dinner"):
                dinner_list.append(string['ID'])
                dinner_count += 1
                score += 1
            if (score > 1):
                multiple_list.append(string['ID'])
                multiple += 1

combined_count = break_count + lunch_count + dinner_count
combined_list = break_list + lunch_list + dinner_list
overlap = not(total == combined_count)
if (overlap is True):
    conclusion = "Recipes exist in more than one meal type."
elif (overlap is False):
    conclusion = "Recipes belong to only one meal type."

# Print findings
print(f"Total recipes with at least one tag: {total}")
print(32*'*')
print(f"Breakfast: {break_count}")
print(f"Lunch: {lunch_count}")
print(f"Dinner: {dinner_count}")
print(32*'*')
print(f"Multiple: {multiple}")
print(f"Checksum: {combined_count}")
print(f"Overlap? {overlap}. {conclusion}")
# Out:
# Total recipes with at least one tag: 529
# ********************************
# Breakfast: 53
# Lunch: 238
# Dinner: 238
# ********************************
# Multiple: 243
# Checksum: 529
# Overlap? False. Recipes belong to only one meal type.

# %%
# Isolate recipes which have: breakfast, lunch, or dinner as a meal type
updated_nutrition = nutrition_unique.loc[nutrition_unique['ID'].isin(combined_list)]
updated_nutrition.shape

# Remove recipes with more than one meal type
updated_nutrition = updated_nutrition.loc[~updated_nutrition['ID'].isin(multiple_list)]
updated_nutrition.shape
# Out:
# (48, 22)

# %%
updated_nutrition
# Out:
#           ID                                               Name  Likes  \
# 2     715497                    Berry Banana Breakfast Smoothie    689
# 17    756814        Powerhouse Almond Matcha Superfood Smoothie     80
# 29    716432      Finger Foods: Frittata Muffins #incredibleEGG    601
# 52    782622          Chocolate Peanut Butter Cinnamon Smoothie      5
# 77    716276                                          Doughnuts    205
# 81    655235                   Peanut Butter and Jelly Smoothie     58
# 106   796873                                     Yogurt Parfait      2
# 110   782598  Toasted Coconut Pancakes with Toasted Coconut ...     38
# 131   157259                             Cocoa Protein Pancakes      8
# 141   639482                             Cinnamon Rolls by Bing      4
# 146   764752                       Cinnamon French Toast Sticks      4
# 151   634781                       Beet Greens and Poached Eggs      4
# 153  1098347                              Homemade Banana Bread      2
# 154   632928                            Asparagus Eggs Benedict    146
# 164   640275                           Crab Cakes Eggs Benedict    700
# 178   639465                         Cinnamon Mocha Quick Bread     37
# 179   634180                              Banana Smoothie Boost      3
# 203   642178                        Egg and Dairy Free Pancakes     18
# 223   640443    Cranberry-Ginger Oatmeal With Toasted Hazelnuts      2
# 231   647555                                           Hotcakes      2
# 247  1003210                           Lemon Poppy Seed Muffins      5
# 289   780726                      Skinny Chocolate Banana Bread      4
# 296   638257                                   Chicken Porridge     19
# 297  1100990  Blueberry, Chocolate & Cocao Superfood Pancake...     15
# 341   639769  Coconut Flour Pancakes with Blueberry Honey Co...      4
# 358   716211                           Cherry Blueberry Muffins     48
# 369   715569             Strawberry Cheesecake Chocolate Crepes   1928
# 387   645530                    Green Tea Fruit Medley Smoothie     62
# 402   660227                      Skinny Green Monster Smoothie      7
# 418   635418                          Blueberry Banana Pancakes     25
# 477   664533                           Vegetable Cheddar Quiche      2
# 505   644690                               Gingerbread Pancakes      2
# 538   655406                        Pear and Walnut Coffee Cake      2
# 546   646348                       Havarti and Asparagus Quiche      3
# 559   655186                          Peaches And Cream Oatmeal      2
# 569   649567                              Lemon Coconut Granola     32
# 580   662303                           Sunday Morning Doughnuts      3
# 584   647261                  Honey Nut Raspberry Baked Oatmeal      9
# 587   637055           Caramelized cranberries coconut pancakes      2
# 594   633998                          Banana Blueberry Pancakes      3
# 601   644810                 Gluten Free Cinnamon Apple Muffins      5
# 605   641650                         Dried Cherry-Almond Scones      2
# 632   647442                                     Hot Cross Buns     11
# 641   638775                             Chive and dill muffins     18
# 655   661758                 Strawberry Banana Stuffed Pancakes     19
# 672   663756                           Traditional Banana Bread      5
# 725   637184                               Carrot Cake Pancakes      2
# 728   635187                          Blackberry Breakfast Bars      2
#
#                                              Meal Type  \
# 2    ['morning meal', 'brunch', 'beverage', 'breakf...
# 17   ['morning meal', 'brunch', 'beverage', 'breakf...
# 29             ['morning meal', 'brunch', 'breakfast']
# 52   ['morning meal', 'brunch', 'beverage', 'breakf...
# 77             ['morning meal', 'brunch', 'breakfast']
# 81   ['morning meal', 'brunch', 'beverage', 'breakf...
# 106            ['morning meal', 'brunch', 'breakfast']
# 110            ['morning meal', 'brunch', 'breakfast']
# 131            ['morning meal', 'brunch', 'breakfast']
# 141            ['morning meal', 'brunch', 'breakfast']
# 146            ['morning meal', 'brunch', 'breakfast']
# 151            ['morning meal', 'brunch', 'breakfast']
# 153  ['morning meal', 'dessert', 'brunch', 'breakfa...
# 154            ['morning meal', 'brunch', 'breakfast']
# 164            ['morning meal', 'brunch', 'breakfast']
# 178  ['morning meal', 'dessert', 'brunch', 'breakfa...
# 179  ['morning meal', 'brunch', 'beverage', 'breakf...
# 203            ['morning meal', 'brunch', 'breakfast']
# 223            ['morning meal', 'brunch', 'breakfast']
# 231            ['morning meal', 'brunch', 'breakfast']
# 247            ['morning meal', 'brunch', 'breakfast']
# 289  ['morning meal', 'dessert', 'brunch', 'breakfa...
# 296            ['morning meal', 'brunch', 'breakfast']
# 297            ['morning meal', 'brunch', 'breakfast']
# 341            ['morning meal', 'brunch', 'breakfast']
# 358            ['morning meal', 'brunch', 'breakfast']
# 369  ['morning meal', 'dessert', 'brunch', 'breakfa...
# 387  ['morning meal', 'brunch', 'beverage', 'breakf...
# 402  ['morning meal', 'brunch', 'beverage', 'breakf...
# 418            ['morning meal', 'brunch', 'breakfast']
# 477  ['antipasti', 'morning meal', 'starter', 'brun...
# 505            ['morning meal', 'brunch', 'breakfast']
# 538  ['morning meal', 'dessert', 'brunch', 'breakfa...
# 546  ['antipasti', 'morning meal', 'starter', 'brun...
# 559            ['morning meal', 'brunch', 'breakfast']
# 569            ['morning meal', 'brunch', 'breakfast']
# 580            ['morning meal', 'brunch', 'breakfast']
# 584            ['morning meal', 'brunch', 'breakfast']
# 587            ['morning meal', 'brunch', 'breakfast']
# 594            ['morning meal', 'brunch', 'breakfast']
# 601            ['morning meal', 'brunch', 'breakfast']
# 605  ['morning meal', 'dessert', 'brunch', 'breakfa...
# 632            ['morning meal', 'brunch', 'breakfast']
# 641            ['morning meal', 'brunch', 'breakfast']
# 655            ['morning meal', 'brunch', 'breakfast']
# 672  ['morning meal', 'dessert', 'brunch', 'breakfa...
# 725            ['morning meal', 'brunch', 'breakfast']
# 728            ['morning meal', 'brunch', 'breakfast']
#
#                                            Cuisines  N_ingredients  \
# 2                                                []              5
# 17                                               []             10
# 29                                               []              8
# 52                                     ['Southern']              6
# 77                                               []              6
# 81                                               []              5
# 106                                              []              6
# 110                                              []             14
# 131                                              []              5
# 141                                              []             20
# 146                                    ['American']              8
# 151                                              []              9
# 153                                              []              9
# 154                                              []              9
# 164                                              []             13
# 178                                              []             11
# 179                                              []              5
# 203                                              []              9
# 223                                              []              8
# 231                                              []              8
# 247                                              []              6
# 289                                              []             10
# 296                                              []             11
# 297                                              []             10
# 341                                              []             10
# 358                                              []             15
# 369         ['Mediterranean', 'French', 'European']             13
# 387                                              []              6
# 402                                              []              5
# 418                                              []              9
# 477         ['Mediterranean', 'French', 'European']             20
# 505                                              []             11
# 538                                              []             23
# 546         ['Mediterranean', 'French', 'European']              9
# 559                                              []              6
# 569                                              []             11
# 580                                              []             10
# 584                                              []              7
# 587                                              []             10
# 594                                              []              8
# 601                                              []              9
# 605  ['English', 'Scottish', 'British', 'European']             10
# 632                                              []             10
# 641                                              []             11
# 655                                              []              9
# 672                                              []             10
# 725                                              []             14
# 728                                              []             11
#
#      WW Smart Points  Calories (Amount) Calories (Unit)  \
# 2               15.0             457.05            kcal
# 17               4.0             387.47            kcal
# 29              19.0             654.73            kcal
# 52               8.0             419.86            kcal
# 77              14.0             430.24            kcal
# 81              26.0            1015.79            kcal
# 106             19.0             691.36            kcal
# 110             21.0             552.20            kcal
# 131             13.0             410.63            kcal
# 141             27.0             665.59            kcal
# 146             24.0             695.14            kcal
# 151              6.0             186.44            kcal
# 153             11.0             305.89            kcal
# 154             27.0             779.55            kcal
# 164             29.0             899.19            kcal
# 178             10.0             264.55            kcal
# 179              0.0              42.50            kcal
# 203              2.0              66.67            kcal
# 223             10.0             381.92            kcal
# 231             13.0             383.66            kcal
# 247              5.0             129.69            kcal
# 289             20.0             632.91            kcal
# 296             10.0             393.05            kcal
# 297             29.0             774.66            kcal
# 341             32.0             753.33            kcal
# 358              5.0             202.29            kcal
# 369             24.0             618.39            kcal
# 387              1.0              45.37            kcal
# 402              5.0             286.46            kcal
# 418             21.0             576.34            kcal
# 477              9.0             573.51            kcal
# 505              5.0             164.84            kcal
# 538             17.0             527.70            kcal
# 546             24.0             536.77            kcal
# 559             12.0             411.92            kcal
# 569              8.0             316.88            kcal
# 580              8.0             183.91            kcal
# 584              8.0             249.79            kcal
# 587             18.0             442.38            kcal
# 594              4.0             173.69            kcal
# 601              1.0              52.92            kcal
# 605              6.0             216.83            kcal
# 632              2.0              85.94            kcal
# 641              6.0             179.51            kcal
# 655              3.0             170.94            kcal
# 672             14.0             370.21            kcal
# 725              4.0             154.17            kcal
# 728             84.0            2679.82            kcal
#
#      Calories (% of Daily Needs)  ...  Saturated Fat (% of Daily Needs)  \
# 2                          22.85  ...                             16.88
# 17                         19.37  ...                             10.19
# 29                         32.74  ...                            120.36
# 52                         20.99  ...                             26.54
# 77                         21.51  ...                              4.92
# 81                         50.79  ...                             43.17
# 106                        34.57  ...                             12.11
# 110                        27.61  ...                            218.60
# 131                        20.53  ...                             28.27
# 141                        33.28  ...                            109.84
# 146                        34.76  ...                             73.92
# 151                         9.32  ...                             51.18
# 153                        15.29  ...                             33.87
# 154                        38.98  ...                            178.35
# 164                        44.96  ...                            131.55
# 178                        13.23  ...                              5.80
# 179                         2.13  ...                              1.46
# 203                         3.33  ...                              1.39
# 223                        19.10  ...                             12.17
# 231                        19.18  ...                             53.87
# 247                         6.48  ...                              6.18
# 289                        31.65  ...                             99.78
# 296                        19.65  ...                              9.86
# 297                        38.73  ...                            168.13
# 341                        37.67  ...                            114.74
# 358                        10.11  ...                              8.90
# 369                        30.92  ...                            135.70
# 387                         2.27  ...                              1.58
# 402                        14.32  ...                             11.72
# 418                        28.82  ...                              1.67
# 477                        28.68  ...                             73.49
# 505                         8.24  ...                             21.92
# 538                        26.39  ...                             66.84
# 546                        26.84  ...                            144.12
# 559                        20.60  ...                             11.67
# 569                        15.84  ...                             64.64
# 580                         9.20  ...                              6.08
# 584                        12.49  ...                              5.99
# 587                        22.12  ...                            135.56
# 594                         8.68  ...                             44.29
# 601                         2.65  ...                              2.53
# 605                        10.84  ...                             19.44
# 632                         4.30  ...                              8.59
# 641                         8.98  ...                             21.64
# 655                         8.55  ...                              1.08
# 672                        18.51  ...                             48.34
# 725                         7.71  ...                             19.42
# 728                       133.99  ...                            125.00
#
#     Sugar (Amount)  Sugar (Unit)  Sugar (% of Daily Needs) Sodium (Amount)  \
# 2            52.28             g                     58.09          400.90
# 17           20.94             g                     23.27          266.10
# 29            5.84             g                      6.49          964.99
# 52           18.83             g                     20.92          505.81
# 77           19.34             g                     21.49          602.56
# 81          106.60             g                    118.45          391.29
# 106          80.66             g                     89.62          404.51
# 110          12.21             g                     13.57          383.35
# 131          15.48             g                     17.20          429.23
# 141          45.54             g                     50.60          467.89
# 146          49.49             g                     54.99          645.19
# 151           1.60             g                      1.78          339.85
# 153          24.39             g                     27.10          279.34
# 154           1.80             g                      2.00         1618.62
# 164           2.69             g                      2.99         2262.47
# 178          26.53             g                     29.48          323.77
# 179           5.59             g                      6.21           54.74
# 203           1.06             g                      1.18          142.77
# 223           4.18             g                      4.64         2345.04
# 231           4.76             g                      5.29          352.95
# 247           9.38             g                     10.42          189.66
# 289          44.23             g                     49.14         1250.04
# 296           7.27             g                      8.08          826.49
# 297           8.44             g                      9.38          342.92
# 341          72.23             g                     80.26          431.85
# 358           7.99             g                      8.88          200.80
# 369          14.57             g                     16.19          331.57
# 387           7.46             g                      8.29           25.30
# 402          17.71             g                     19.68          396.80
# 418          96.61             g                    107.34         1558.57
# 477           2.15             g                      2.39          687.58
# 505           5.48             g                      6.08          398.48
# 538          49.23             g                     54.70          239.61
# 546          26.23             g                     29.14          398.16
# 559          17.96             g                     19.96           93.55
# 569          18.48             g                     20.53           15.49
# 580          23.78             g                     26.42          279.31
# 584          18.33             g                     20.37           23.03
# 587           7.52             g                      8.36          542.26
# 594           9.47             g                     10.53           43.51
# 601           7.22             g                      8.02           16.92
# 605           5.74             g                      6.38          197.73
# 632           4.91             g                      5.45          282.46
# 641           3.26             g                      3.62          452.45
# 655          12.01             g                     13.35          530.69
# 672          30.63             g                     34.03          502.19
# 725           7.87             g                      8.74          260.50
# 728         324.25             g                    360.28         1297.74
#
#      Sodium (Unit)  Sodium (% of Daily Needs) Protein (Amount)  \
# 2               mg                      17.43            20.62
# 17              mg                      11.57             0.34
# 29              mg                      41.96            49.45
# 52              mg                      21.99            27.08
# 77              mg                      26.20            11.36
# 81              mg                      17.01            19.90
# 106             mg                      17.59            35.90
# 110             mg                      16.67             8.17
# 131             mg                      18.66             5.75
# 141             mg                      20.34            74.29
# 146             mg                      28.05            23.32
# 151             mg                      14.78            10.30
# 153             mg                      12.15             4.42
# 154             mg                      70.37            34.72
# 164             mg                      98.37            42.16
# 178             mg                      14.08             6.61
# 179             mg                       2.38             0.58
# 203             mg                       6.21             1.41
# 223             mg                     101.96            10.38
# 231             mg                      15.35             0.34
# 247             mg                       8.25             1.98
# 289             mg                      54.35             0.48
# 296             mg                      35.93            27.74
# 297             mg                      14.91            13.02
# 341             mg                      18.78            15.94
# 358             mg                       8.73             0.23
# 369             mg                      14.42             0.54
# 387             mg                       1.10             1.80
# 402             mg                      17.25            17.65
# 418             mg                      67.76             0.69
# 477             mg                      29.89            11.08
# 505             mg                      17.33             3.69
# 538             mg                      10.42             6.68
# 546             mg                      17.31            11.73
# 559             mg                       4.07            16.48
# 569             mg                       0.67             6.31
# 580             mg                      12.14             3.11
# 584             mg                       1.00             0.24
# 587             mg                      23.58             0.29
# 594             mg                       1.89             4.26
# 601             mg                       0.74             1.55
# 605             mg                       8.60             5.54
# 632             mg                      12.28             0.79
# 641             mg                      19.67             5.47
# 655             mg                      23.07             0.34
# 672             mg                      21.83             5.51
# 725             mg                      11.33             3.77
# 728             mg                      56.42            23.01
#
#      Protein (Unit)  Protein (% of Daily Needs)
# 2                 g                       41.25
# 17                g                        1.91
# 29                g                       98.89
# 52                g                       54.16
# 77                g                       22.73
# 81                g                       39.79
# 106               g                       71.80
# 110               g                       16.34
# 131              mg                        1.92
# 141              mg                       24.76
# 146               g                       46.63
# 151               g                       20.59
# 153               g                        8.84
# 154               g                       69.45
# 164               g                       84.32
# 178              mg                        2.20
# 179               g                        1.15
# 203               g                        2.82
# 223               g                       20.76
# 231               g                        1.91
# 247               g                        3.97
# 289               g                        2.68
# 296               g                       55.48
# 297               g                       26.04
# 341               g                       31.88
# 358               g                        1.27
# 369               g                        3.01
# 387               g                        3.61
# 402               g                       35.31
# 418               g                        3.82
# 477               g                       22.16
# 505               g                        7.38
# 538               g                       13.36
# 546               g                       23.45
# 559               g                       32.97
# 569               g                       12.62
# 580               g                        6.23
# 584               g                        1.34
# 587               g                        1.61
# 594               g                        8.52
# 601               g                        3.09
# 605               g                       11.09
# 632               g                        1.57
# 641               g                       10.94
# 655               g                        1.91
# 672               g                       11.01
# 725               g                        7.54
# 728               g                       46.03
#
# [48 rows x 22 columns]

# %%
column_all = [list(nutrition7_df.columns),list(nutrition1_df.columns),list(nutrition2_df.columns),list(nutrition3_df.columns),list(nutrition4_df.columns),
         list(nutrition5_df.columns),list(nutrition0_df.columns),list(nutrition10_df.columns),list(nutrition11_df.columns)]

# %%
nutrition7_columns = pd.DataFrame(column_all).transpose()
nutrition7_columns.columns = ['nutrition7_columns','nutrition1_columns','nutrition2_columns','nutrition3_columns',
                             'nutrition4_columns','nutrition5_columns','nutrition0_columns',
                             'nutrition10_columns','nutrition11_columns']
nutrition7_columns
# Out:
#                   nutrition7_columns                nutrition1_columns  \
# 0                                 ID                                ID
# 1                               Name                              Name
# 2                              Likes                             Likes
# 3                          Meal Type                         Meal Type
# 4                           Cuisines                          Cuisines
# 5                      N_ingredients                     N_ingredients
# 6                    WW Smart Points                   WW Smart Points
# 7                  Calories (Amount)                 Calories (Amount)
# 8                    Calories (Unit)                   Calories (Unit)
# 9        Calories (% of Daily Needs)       Calories (% of Daily Needs)
# 10            Saturated Fat (Amount)            Saturated Fat (Amount)
# 11              Saturated Fat (Unit)              Saturated Fat (Unit)
# 12  Saturated Fat (% of Daily Needs)  Saturated Fat (% of Daily Needs)
# 13                    Sugar (Amount)                    Sugar (Amount)
# 14                      Sugar (Unit)                      Sugar (Unit)
# 15          Sugar (% of Daily Needs)          Sugar (% of Daily Needs)
# 16                   Sodium (Amount)                   Sodium (Amount)
# 17                     Sodium (Unit)                     Sodium (Unit)
# 18         Sodium (% of Daily Needs)         Sodium (% of Daily Needs)
# 19                  Protein (Amount)                  Protein (Amount)
# 20                    Protein (Unit)                    Protein (Unit)
# 21        Protein (% of Daily Needs)        Protein (% of Daily Needs)
# 22                     Carbohydrates                              None
#
#                   nutrition2_columns                nutrition3_columns  \
# 0                                 ID                                ID
# 1                               Name                              Name
# 2                              Likes                             Likes
# 3                          Meal Type                         Meal Type
# 4                           Cuisines                          Cuisines
# 5                      N_ingredients                     N_ingredients
# 6                    WW Smart Points                   WW Smart Points
# 7                  Calories (Amount)                 Calories (Amount)
# 8                    Calories (Unit)                   Calories (Unit)
# 9        Calories (% of Daily Needs)       Calories (% of Daily Needs)
# 10            Saturated Fat (Amount)            Saturated Fat (Amount)
# 11              Saturated Fat (Unit)              Saturated Fat (Unit)
# 12  Saturated Fat (% of Daily Needs)  Saturated Fat (% of Daily Needs)
# 13                    Sugar (Amount)                    Sugar (Amount)
# 14                      Sugar (Unit)                      Sugar (Unit)
# 15          Sugar (% of Daily Needs)          Sugar (% of Daily Needs)
# 16                   Sodium (Amount)                   Sodium (Amount)
# 17                     Sodium (Unit)                     Sodium (Unit)
# 18         Sodium (% of Daily Needs)         Sodium (% of Daily Needs)
# 19                  Protein (Amount)                  Protein (Amount)
# 20                    Protein (Unit)                    Protein (Unit)
# 21        Protein (% of Daily Needs)        Protein (% of Daily Needs)
# 22                              None                              None
#
#                   nutrition4_columns                nutrition5_columns  \
# 0                                 ID                                ID
# 1                               Name                              Name
# 2                              Likes                             Likes
# 3                          Meal Type                         Meal Type
# 4                           Cuisines                          Cuisines
# 5                      N_ingredients                     N_ingredients
# 6                    WW Smart Points                   WW Smart Points
# 7                  Calories (Amount)                 Calories (Amount)
# 8                    Calories (Unit)                   Calories (Unit)
# 9        Calories (% of Daily Needs)       Calories (% of Daily Needs)
# 10            Saturated Fat (Amount)            Saturated Fat (Amount)
# 11              Saturated Fat (Unit)              Saturated Fat (Unit)
# 12  Saturated Fat (% of Daily Needs)  Saturated Fat (% of Daily Needs)
# 13                    Sugar (Amount)                    Sugar (Amount)
# 14                      Sugar (Unit)                      Sugar (Unit)
# 15          Sugar (% of Daily Needs)          Sugar (% of Daily Needs)
# 16                   Sodium (Amount)                   Sodium (Amount)
# 17                     Sodium (Unit)                     Sodium (Unit)
# 18         Sodium (% of Daily Needs)         Sodium (% of Daily Needs)
# 19                  Protein (Amount)                  Protein (Amount)
# 20                    Protein (Unit)                    Protein (Unit)
# 21        Protein (% of Daily Needs)        Protein (% of Daily Needs)
# 22                              None                     Carbohydrates
#
#                   nutrition0_columns               nutrition10_columns  \
# 0                                 ID                                ID
# 1                               Name                              Name
# 2                              Likes                             Likes
# 3                          Meal Type                         Meal Type
# 4                           Cuisines                          Cuisines
# 5                      N_ingredients                     N_ingredients
# 6                    WW Smart Points                   WW Smart Points
# 7                  Calories (Amount)                 Calories (Amount)
# 8                    Calories (Unit)                   Calories (Unit)
# 9        Calories (% of Daily Needs)       Calories (% of Daily Needs)
# 10            Saturated Fat (Amount)            Saturated Fat (Amount)
# 11              Saturated Fat (Unit)              Saturated Fat (Unit)
# 12  Saturated Fat (% of Daily Needs)  Saturated Fat (% of Daily Needs)
# 13                    Sugar (Amount)                    Sugar (Amount)
# 14                      Sugar (Unit)                      Sugar (Unit)
# 15          Sugar (% of Daily Needs)          Sugar (% of Daily Needs)
# 16                   Sodium (Amount)                   Sodium (Amount)
# 17                     Sodium (Unit)                     Sodium (Unit)
# 18         Sodium (% of Daily Needs)         Sodium (% of Daily Needs)
# 19                  Protein (Amount)                  Protein (Amount)
# 20                    Protein (Unit)                    Protein (Unit)
# 21        Protein (% of Daily Needs)        Protein (% of Daily Needs)
# 22                              None                     Carbohydrates
#
#                  nutrition11_columns
# 0                                 ID
# 1                               Name
# 2                              Likes
# 3                          Meal Type
# 4                           Cuisines
# 5                      N_ingredients
# 6                    WW Smart Points
# 7                  Calories (Amount)
# 8                    Calories (Unit)
# 9        Calories (% of Daily Needs)
# 10            Saturated Fat (Amount)
# 11              Saturated Fat (Unit)
# 12  Saturated Fat (% of Daily Needs)
# 13                    Sugar (Amount)
# 14                      Sugar (Unit)
# 15          Sugar (% of Daily Needs)
# 16                   Sodium (Amount)
# 17                     Sodium (Unit)
# 18         Sodium (% of Daily Needs)
# 19                  Protein (Amount)
# 20                    Protein (Unit)
# 21        Protein (% of Daily Needs)
# 22                     Carbohydrates

# %%
#compare column name using nutrition7_columns. 
# missing columns of "nutrition1_df" are "WW Smart Points" and "Carbohydrates".
# missing columns of "nutrition2_df" are "WW Smart Points" and "Carbohydrates".
# missing columns of "nutrition3_df" are "WW Smart Points" and "Carbohydrates".
# missing columns of "nutrition4_df" is  "Carbohydrates".
# missing columns of "nutrition0_df" is "Carbohydrates".

# %%
nutrition0_df.count()
# Out:
# ID                                  100
# Name                                100
# Likes                               100
# Meal Type                           100
# Cuisines                            100
# N_ingredients                       100
# WW Smart Points                     100
# Calories (Amount)                   100
# Calories (Unit)                     100
# Calories (% of Daily Needs)         100
# Saturated Fat (Amount)              100
# Saturated Fat (Unit)                100
# Saturated Fat (% of Daily Needs)    100
# Sugar (Amount)                      100
# Sugar (Unit)                        100
# Sugar (% of Daily Needs)            100
# Sodium (Amount)                     100
# Sodium (Unit)                       100
# Sodium (% of Daily Needs)           100
# Protein (Amount)                    100
# Protein (Unit)                      100
# Protein (% of Daily Needs)          100
# dtype: int64

# %%
nutrition1_df.count()
# Out:
# ID                                  33
# Name                                33
# Likes                               33
# Meal Type                           33
# Cuisines                            33
# N_ingredients                       33
# WW Smart Points                     33
# Calories (Amount)                   33
# Calories (Unit)                     33
# Calories (% of Daily Needs)         33
# Saturated Fat (Amount)              33
# Saturated Fat (Unit)                33
# Saturated Fat (% of Daily Needs)    33
# Sugar (Amount)                      33
# Sugar (Unit)                        33
# Sugar (% of Daily Needs)            33
# Sodium (Amount)                     33
# Sodium (Unit)                       33
# Sodium (% of Daily Needs)           33
# Protein (Amount)                    33
# Protein (Unit)                      33
# Protein (% of Daily Needs)          33
# dtype: int64

# %%
nutrition2_df.count()
# Out:
# ID                                  100
# Name                                100
# Likes                               100
# Meal Type                           100
# Cuisines                            100
# N_ingredients                       100
# WW Smart Points                     100
# Calories (Amount)                   100
# Calories (Unit)                     100
# Calories (% of Daily Needs)         100
# Saturated Fat (Amount)              100
# Saturated Fat (Unit)                100
# Saturated Fat (% of Daily Needs)    100
# Sugar (Amount)                      100
# Sugar (Unit)                        100
# Sugar (% of Daily Needs)            100
# Sodium (Amount)                     100
# Sodium (Unit)                       100
# Sodium (% of Daily Needs)           100
# Protein (Amount)                    100
# Protein (Unit)                      100
# Protein (% of Daily Needs)          100
# dtype: int64

# %%
nutrition3_df.count()
# Out:
# ID                                  33
# Name                                33
# Likes                               33
# Meal Type                           33
# Cuisines                            33
# N_ingredients                       33
# WW Smart Points                     33
# Calories (Amount)                   33
# Calories (Unit)                     33
# Calories (% of Daily Needs)         33
# Saturated Fat (Amount)              33
# Saturated Fat (Unit)                33
# Saturated Fat (% of Daily Needs)    33
# Sugar (Amount)                      33
# Sugar (Unit)                        33
# Sugar (% of Daily Needs)            33
# Sodium (Amount)                     33
# Sodium (Unit)                       33
# Sodium (% of Daily Needs)           33
# Protein (Amount)                    33
# Protein (Unit)                      33
# Protein (% of Daily Needs)          33
# dtype: int64

# %%
nutrition4_df.count()
# Out:
# ID                                  100
# Name                                100
# Likes                               100
# Meal Type                           100
# Cuisines                            100
# N_ingredients                       100
# WW Smart Points                     100
# Calories (Amount)                   100
# Calories (Unit)                     100
# Calories (% of Daily Needs)         100
# Saturated Fat (Amount)              100
# Saturated Fat (Unit)                100
# Saturated Fat (% of Daily Needs)    100
# Sugar (Amount)                      100
# Sugar (Unit)                        100
# Sugar (% of Daily Needs)            100
# Sodium (Amount)                     100
# Sodium (Unit)                       100
# Sodium (% of Daily Needs)           100
# Protein (Amount)                    100
# Protein (Unit)                      100
# Protein (% of Daily Needs)          100
# dtype: int64

# %%
nutrition5_df.count()
# Out:
# ID                                  100
# Name                                100
# Likes                               100
# Meal Type                           100
# Cuisines                            100
# N_ingredients                       100
# WW Smart Points                     100
# Calories (Amount)                   100
# Calories (Unit)                     100
# Calories (% of Daily Needs)         100
# Saturated Fat (Amount)              100
# Saturated Fat (Unit)                100
# Saturated Fat (% of Daily Needs)    100
# Sugar (Amount)                      100
# Sugar (Unit)                        100
# Sugar (% of Daily Needs)            100
# Sodium (Amount)                     100
# Sodium (Unit)                       100
# Sodium (% of Daily Needs)           100
# Protein (Amount)                    100
# Protein (Unit)                      100
# Protein (% of Daily Needs)          100
# Carbohydrates                       100
# dtype: int64

# %%
nutrition7_df.count()
# Out:
# ID                                  100
# Name                                100
# Likes                               100
# Meal Type                           100
# Cuisines                            100
# N_ingredients                       100
# WW Smart Points                     100
# Calories (Amount)                   100
# Calories (Unit)                     100
# Calories (% of Daily Needs)         100
# Saturated Fat (Amount)              100
# Saturated Fat (Unit)                100
# Saturated Fat (% of Daily Needs)    100
# Sugar (Amount)                      100
# Sugar (Unit)                        100
# Sugar (% of Daily Needs)            100
# Sodium (Amount)                     100
# Sodium (Unit)                       100
# Sodium (% of Daily Needs)           100
# Protein (Amount)                    100
# Protein (Unit)                      100
# Protein (% of Daily Needs)          100
# Carbohydrates                       100
# dtype: int64

# %%
nutrition10_df.count()
# Out:
# ID                                  100
# Name                                100
# Likes                               100
# Meal Type                           100
# Cuisines                            100
# N_ingredients                       100
# WW Smart Points                     100
# Calories (Amount)                   100
# Calories (Unit)                     100
# Calories (% of Daily Needs)         100
# Saturated Fat (Amount)              100
# Saturated Fat (Unit)                100
# Saturated Fat (% of Daily Needs)    100
# Sugar (Amount)                      100
# Sugar (Unit)                        100
# Sugar (% of Daily Needs)            100
# Sodium (Amount)                     100
# Sodium (Unit)                       100
# Sodium (% of Daily Needs)           100
# Protein (Amount)                    100
# Protein (Unit)                      100
# Protein (% of Daily Needs)          100
# Carbohydrates                       100
# dtype: int64

# %%
nutrition11_df.count()
# Out:
# ID                                  100
# Name                                100
# Likes                               100
# Meal Type                           100
# Cuisines                            100
# N_ingredients                       100
# WW Smart Points                     100
# Calories (Amount)                   100
# Calories (Unit)                     100
# Calories (% of Daily Needs)         100
# Saturated Fat (Amount)              100
# Saturated Fat (Unit)                100
# Saturated Fat (% of Daily Needs)    100
# Sugar (Amount)                      100
# Sugar (Unit)                        100
# Sugar (% of Daily Needs)            100
# Sodium (Amount)                     100
# Sodium (Unit)                       100
# Sodium (% of Daily Needs)           100
# Protein (Amount)                    100
# Protein (Unit)                      100
# Protein (% of Daily Needs)          100
# Carbohydrates                       100
# dtype: int64

# %%
# No missing values in each csv's
